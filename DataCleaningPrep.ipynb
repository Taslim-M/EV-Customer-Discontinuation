# %%
import pandas as pd

# %%
df = pd.read_csv('Data/Discontinaunce_of_PEVs_in_California_Data_2021.03.01.csv',index_col=0)

# %%
df.head()
# Out:
#                     Year Submitted Survey 2   Months Owned (total)  \
# ﻿"id. Response ID"
# 1.0                                  2019.0                   24.0
# 2.0                                  2019.0                   20.0
# 3.0                                  2019.0                   23.0
# 4.0                                  2019.0                   45.0
# 5.0                                  2019.0                   19.0
#
#                                        oldcarmain  Electric driving range  \
# ﻿"id. Response ID"
# 1.0                                   2016 BMW i3                    81.0
# 2.0                 2018 Tesla Model 3 Long Range                   310.0
# 3.0                           2017 Chevrolet Volt                    53.0
# 4.0                            2016 Tesla Model S                   271.0
# 5.0                              2019 Nissan Leaf                    84.0
#
# ...

# %%
df.columns
# Out:
# Index(['Year Submitted Survey 2', ' Months Owned (total)', 'oldcarmain',
#        'Electric driving range', 'oldcartype',
#        'Discontinuance (inc. purchased lease) 2', 'Age', 'Gender',
#        'dist1  [Route 1]',
#        'How many road trips longer than 200 miles round-trip did you or your household complete with each car in the last 12 months (or the time you own the car if less than that)?  [{oldcarmain.NAOK}]',
#        '{oldcarmain.NAOK} [Safety]', 'Comfort', 'Refuelling/Recharging costs',
#        'Performance', 'Environmental impacts',
#        'Vehicle Purchase Price (including rebates, discounts, etc.)',
#        'Reliability', 'Electric driving range.1', 'Convenience of charging',
#        'Driving assistance features',
#        'My household's pre-taxed income for the past tax year was in the following range',
#        'Home Charging (L1, L2, None)', 'Work charging (L1, L2, DC, none)',
#        'Concatenate[[s]...s] Public DCFC] 2', 'MPG second vehicle in HH 2',
# ...

# %%
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
missing_values_table(df)
# Out:
# Your selected dataframe has 27 columns.
# There are 27 columns that have missing values.
#                                                     Missing Values  \
# Work charging (L1, L2, DC, none)                              1661
# Concatenate[[s]...s] Public DCFC] 2                           1282
# MPG second vehicle in HH 2                                    1046
# dist1  [Route 1]                                              1024
# My household's pre-taxed income for the past ta...             747
# Refuelling/Recharging costs                                    689
# Driving assistance features                                    689
# Convenience of charging                                        689
# Electric driving range.1                                       689
# Reliability                                                    689
# Vehicle Purchase Price (including rebates, disc...             689
# Environmental impacts                                          689
# ...

# %%
df['Discontinuance (inc. purchased lease) 2'].value_counts()
# Out:
# Original        2886
# Continued       1530
# Discontinued     417
# Name: Discontinuance (inc. purchased lease) 2, dtype: int64

# %%
df_disc = df[df['Discontinuance (inc. purchased lease) 2']=='Discontinued']

# %%
missing_values_table(df_disc)
# Out:
# Your selected dataframe has 27 columns.
# There are 19 columns that have missing values.
#                                                     Missing Values  \
# Work charging (L1, L2, DC, none)                               192
# Concatenate[[s]...s] Public DCFC] 2                            165
# dist1  [Route 1]                                               101
# MPG second vehicle in HH 2                                      95
# My household's pre-taxed income for the past ta...              60
# Vehicle Purchase Price (including rebates, disc...              51
# Driving assistance features                                     51
# Convenience of charging                                         51
# Electric driving range.1                                        51
# Reliability                                                     51
# Environmental impacts                                           51
# Performance                                                     51
# ...
