# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pylab as pl
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc

from sklearn import datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
X_train = np.load('Data/X_train.npy', allow_pickle= True)
y_train = np.load('Data/Y_train.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 893 893 384 384

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier #import the DT classifier


tuned_parameters = [{
    'min_samples_split': [i for i in range(5,80,5)], 
    'max_leaf_nodes':  [k for k in range(5,80,5)]
    }]

clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'max_leaf_nodes': 30, 'min_samples_split': 75}
#
#  Best Score 0.766623766282094
#
#  Grid scores on development set:
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 5}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 10}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 15}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 20}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 25}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 30}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 35}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 40}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 45}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 50}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 55}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 60}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 65}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 70}
# 0.752 (+/-0.041) for {'max_leaf_nodes': 5, 'min_samples_split': 75}
# 0.746 (+/-0.038) for {'max_leaf_nodes': 10, 'min_samples_split': 5}
# 0.746 (+/-0.038) for {'max_leaf_nodes': 10, 'min_samples_split': 10}
# 0.746 (+/-0.038) for {'max_leaf_nodes': 10, 'min_samples_split': 15}
# 0.746 (+/-0.038) for {'max_leaf_nodes': 10, 'min_samples_split': 20}
# 0.745 (+/-0.037) for {'max_leaf_nodes': 10, 'min_samples_split': 25}
# 0.741 (+/-0.046) for {'max_leaf_nodes': 10, 'min_samples_split': 30}
# 0.741 (+/-0.046) for {'max_leaf_nodes': 10, 'min_samples_split': 35}
# 0.741 (+/-0.046) for {'max_leaf_nodes': 10, 'min_samples_split': 40}
# 0.741 (+/-0.046) for {'max_leaf_nodes': 10, 'min_samples_split': 45}
# 0.741 (+/-0.046) for {'max_leaf_nodes': 10, 'min_samples_split': 50}
# 0.741 (+/-0.046) for {'max_leaf_nodes': 10, 'min_samples_split': 55}
# 0.741 (+/-0.046) for {'max_leaf_nodes': 10, 'min_samples_split': 60}
# 0.749 (+/-0.038) for {'max_leaf_nodes': 10, 'min_samples_split': 65}
# 0.754 (+/-0.041) for {'max_leaf_nodes': 10, 'min_samples_split': 70}
# 0.756 (+/-0.041) for {'max_leaf_nodes': 10, 'min_samples_split': 75}
# 0.748 (+/-0.035) for {'max_leaf_nodes': 15, 'min_samples_split': 5}
# 0.747 (+/-0.035) for {'max_leaf_nodes': 15, 'min_samples_split': 10}
# 0.747 (+/-0.035) for {'max_leaf_nodes': 15, 'min_samples_split': 15}
# 0.745 (+/-0.033) for {'max_leaf_nodes': 15, 'min_samples_split': 20}
# 0.745 (+/-0.034) for {'max_leaf_nodes': 15, 'min_samples_split': 25}
# 0.744 (+/-0.045) for {'max_leaf_nodes': 15, 'min_samples_split': 30}
# 0.747 (+/-0.045) for {'max_leaf_nodes': 15, 'min_samples_split': 35}
# 0.745 (+/-0.044) for {'max_leaf_nodes': 15, 'min_samples_split': 40}
# 0.745 (+/-0.044) for {'max_leaf_nodes': 15, 'min_samples_split': 45}
# 0.743 (+/-0.045) for {'max_leaf_nodes': 15, 'min_samples_split': 50}
# 0.750 (+/-0.024) for {'max_leaf_nodes': 15, 'min_samples_split': 55}
# 0.750 (+/-0.024) for {'max_leaf_nodes': 15, 'min_samples_split': 60}
# 0.757 (+/-0.019) for {'max_leaf_nodes': 15, 'min_samples_split': 65}
# 0.760 (+/-0.023) for {'max_leaf_nodes': 15, 'min_samples_split': 70}
# 0.762 (+/-0.021) for {'max_leaf_nodes': 15, 'min_samples_split': 75}
# 0.740 (+/-0.033) for {'max_leaf_nodes': 20, 'min_samples_split': 5}
# 0.742 (+/-0.034) for {'max_leaf_nodes': 20, 'min_samples_split': 10}
# 0.741 (+/-0.036) for {'max_leaf_nodes': 20, 'min_samples_split': 15}
# 0.741 (+/-0.033) for {'max_leaf_nodes': 20, 'min_samples_split': 20}
# 0.746 (+/-0.031) for {'max_leaf_nodes': 20, 'min_samples_split': 25}
# 0.751 (+/-0.027) for {'max_leaf_nodes': 20, 'min_samples_split': 30}
# 0.747 (+/-0.031) for {'max_leaf_nodes': 20, 'min_samples_split': 35}
# 0.757 (+/-0.023) for {'max_leaf_nodes': 20, 'min_samples_split': 40}
# 0.757 (+/-0.031) for {'max_leaf_nodes': 20, 'min_samples_split': 45}
# 0.758 (+/-0.029) for {'max_leaf_nodes': 20, 'min_samples_split': 50}
# 0.758 (+/-0.029) for {'max_leaf_nodes': 20, 'min_samples_split': 55}
# 0.752 (+/-0.023) for {'max_leaf_nodes': 20, 'min_samples_split': 60}
# 0.757 (+/-0.021) for {'max_leaf_nodes': 20, 'min_samples_split': 65}
# 0.762 (+/-0.021) for {'max_leaf_nodes': 20, 'min_samples_split': 70}
# 0.766 (+/-0.021) for {'max_leaf_nodes': 20, 'min_samples_split': 75}
# 0.747 (+/-0.044) for {'max_leaf_nodes': 25, 'min_samples_split': 5}
# 0.741 (+/-0.044) for {'max_leaf_nodes': 25, 'min_samples_split': 10}
# 0.745 (+/-0.035) for {'max_leaf_nodes': 25, 'min_samples_split': 15}
# 0.749 (+/-0.024) for {'max_leaf_nodes': 25, 'min_samples_split': 20}
# 0.756 (+/-0.023) for {'max_leaf_nodes': 25, 'min_samples_split': 25}
# 0.758 (+/-0.031) for {'max_leaf_nodes': 25, 'min_samples_split': 30}
# 0.753 (+/-0.038) for {'max_leaf_nodes': 25, 'min_samples_split': 35}
# 0.756 (+/-0.033) for {'max_leaf_nodes': 25, 'min_samples_split': 40}
# 0.764 (+/-0.022) for {'max_leaf_nodes': 25, 'min_samples_split': 45}
# 0.758 (+/-0.032) for {'max_leaf_nodes': 25, 'min_samples_split': 50}
# 0.755 (+/-0.031) for {'max_leaf_nodes': 25, 'min_samples_split': 55}
# 0.750 (+/-0.026) for {'max_leaf_nodes': 25, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 25, 'min_samples_split': 65}
# 0.758 (+/-0.023) for {'max_leaf_nodes': 25, 'min_samples_split': 70}
# 0.764 (+/-0.019) for {'max_leaf_nodes': 25, 'min_samples_split': 75}
# 0.751 (+/-0.032) for {'max_leaf_nodes': 30, 'min_samples_split': 5}
# 0.753 (+/-0.031) for {'max_leaf_nodes': 30, 'min_samples_split': 10}
# 0.744 (+/-0.029) for {'max_leaf_nodes': 30, 'min_samples_split': 15}
# 0.752 (+/-0.023) for {'max_leaf_nodes': 30, 'min_samples_split': 20}
# 0.761 (+/-0.021) for {'max_leaf_nodes': 30, 'min_samples_split': 25}
# 0.757 (+/-0.030) for {'max_leaf_nodes': 30, 'min_samples_split': 30}
# 0.760 (+/-0.028) for {'max_leaf_nodes': 30, 'min_samples_split': 35}
# 0.753 (+/-0.033) for {'max_leaf_nodes': 30, 'min_samples_split': 40}
# 0.758 (+/-0.027) for {'max_leaf_nodes': 30, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 30, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 30, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 30, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 30, 'min_samples_split': 65}
# 0.758 (+/-0.023) for {'max_leaf_nodes': 30, 'min_samples_split': 70}
# 0.767 (+/-0.021) for {'max_leaf_nodes': 30, 'min_samples_split': 75}
# 0.743 (+/-0.028) for {'max_leaf_nodes': 35, 'min_samples_split': 5}
# 0.748 (+/-0.026) for {'max_leaf_nodes': 35, 'min_samples_split': 10}
# 0.748 (+/-0.036) for {'max_leaf_nodes': 35, 'min_samples_split': 15}
# 0.750 (+/-0.023) for {'max_leaf_nodes': 35, 'min_samples_split': 20}
# 0.758 (+/-0.027) for {'max_leaf_nodes': 35, 'min_samples_split': 25}
# 0.753 (+/-0.038) for {'max_leaf_nodes': 35, 'min_samples_split': 30}
# 0.751 (+/-0.037) for {'max_leaf_nodes': 35, 'min_samples_split': 35}
# 0.757 (+/-0.028) for {'max_leaf_nodes': 35, 'min_samples_split': 40}
# 0.758 (+/-0.027) for {'max_leaf_nodes': 35, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 35, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 35, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 35, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 35, 'min_samples_split': 65}
# 0.760 (+/-0.020) for {'max_leaf_nodes': 35, 'min_samples_split': 70}
# 0.767 (+/-0.021) for {'max_leaf_nodes': 35, 'min_samples_split': 75}
# 0.750 (+/-0.033) for {'max_leaf_nodes': 40, 'min_samples_split': 5}
# 0.747 (+/-0.026) for {'max_leaf_nodes': 40, 'min_samples_split': 10}
# 0.744 (+/-0.036) for {'max_leaf_nodes': 40, 'min_samples_split': 15}
# 0.751 (+/-0.022) for {'max_leaf_nodes': 40, 'min_samples_split': 20}
# 0.763 (+/-0.018) for {'max_leaf_nodes': 40, 'min_samples_split': 25}
# 0.751 (+/-0.029) for {'max_leaf_nodes': 40, 'min_samples_split': 30}
# 0.752 (+/-0.036) for {'max_leaf_nodes': 40, 'min_samples_split': 35}
# 0.753 (+/-0.033) for {'max_leaf_nodes': 40, 'min_samples_split': 40}
# 0.758 (+/-0.027) for {'max_leaf_nodes': 40, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 40, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 40, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 40, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 40, 'min_samples_split': 65}
# 0.758 (+/-0.023) for {'max_leaf_nodes': 40, 'min_samples_split': 70}
# 0.767 (+/-0.021) for {'max_leaf_nodes': 40, 'min_samples_split': 75}
# 0.752 (+/-0.029) for {'max_leaf_nodes': 45, 'min_samples_split': 5}
# 0.737 (+/-0.030) for {'max_leaf_nodes': 45, 'min_samples_split': 10}
# 0.741 (+/-0.036) for {'max_leaf_nodes': 45, 'min_samples_split': 15}
# 0.748 (+/-0.017) for {'max_leaf_nodes': 45, 'min_samples_split': 20}
# 0.754 (+/-0.024) for {'max_leaf_nodes': 45, 'min_samples_split': 25}
# 0.754 (+/-0.030) for {'max_leaf_nodes': 45, 'min_samples_split': 30}
# 0.752 (+/-0.036) for {'max_leaf_nodes': 45, 'min_samples_split': 35}
# 0.757 (+/-0.028) for {'max_leaf_nodes': 45, 'min_samples_split': 40}
# 0.758 (+/-0.027) for {'max_leaf_nodes': 45, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 45, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 45, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 45, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 45, 'min_samples_split': 65}
# 0.760 (+/-0.020) for {'max_leaf_nodes': 45, 'min_samples_split': 70}
# 0.764 (+/-0.019) for {'max_leaf_nodes': 45, 'min_samples_split': 75}
# 0.741 (+/-0.031) for {'max_leaf_nodes': 50, 'min_samples_split': 5}
# 0.741 (+/-0.026) for {'max_leaf_nodes': 50, 'min_samples_split': 10}
# 0.743 (+/-0.038) for {'max_leaf_nodes': 50, 'min_samples_split': 15}
# 0.751 (+/-0.017) for {'max_leaf_nodes': 50, 'min_samples_split': 20}
# 0.753 (+/-0.026) for {'max_leaf_nodes': 50, 'min_samples_split': 25}
# 0.754 (+/-0.030) for {'max_leaf_nodes': 50, 'min_samples_split': 30}
# 0.756 (+/-0.030) for {'max_leaf_nodes': 50, 'min_samples_split': 35}
# 0.753 (+/-0.033) for {'max_leaf_nodes': 50, 'min_samples_split': 40}
# 0.758 (+/-0.027) for {'max_leaf_nodes': 50, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 50, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 50, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 50, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 50, 'min_samples_split': 65}
# 0.760 (+/-0.020) for {'max_leaf_nodes': 50, 'min_samples_split': 70}
# 0.767 (+/-0.021) for {'max_leaf_nodes': 50, 'min_samples_split': 75}
# 0.744 (+/-0.032) for {'max_leaf_nodes': 55, 'min_samples_split': 5}
# 0.731 (+/-0.026) for {'max_leaf_nodes': 55, 'min_samples_split': 10}
# 0.736 (+/-0.030) for {'max_leaf_nodes': 55, 'min_samples_split': 15}
# 0.744 (+/-0.018) for {'max_leaf_nodes': 55, 'min_samples_split': 20}
# 0.756 (+/-0.018) for {'max_leaf_nodes': 55, 'min_samples_split': 25}
# 0.752 (+/-0.028) for {'max_leaf_nodes': 55, 'min_samples_split': 30}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 55, 'min_samples_split': 35}
# 0.753 (+/-0.033) for {'max_leaf_nodes': 55, 'min_samples_split': 40}
# 0.754 (+/-0.033) for {'max_leaf_nodes': 55, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 55, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 55, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 55, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 55, 'min_samples_split': 65}
# 0.758 (+/-0.023) for {'max_leaf_nodes': 55, 'min_samples_split': 70}
# 0.764 (+/-0.019) for {'max_leaf_nodes': 55, 'min_samples_split': 75}
# 0.737 (+/-0.032) for {'max_leaf_nodes': 60, 'min_samples_split': 5}
# 0.731 (+/-0.019) for {'max_leaf_nodes': 60, 'min_samples_split': 10}
# 0.729 (+/-0.032) for {'max_leaf_nodes': 60, 'min_samples_split': 15}
# 0.741 (+/-0.019) for {'max_leaf_nodes': 60, 'min_samples_split': 20}
# 0.757 (+/-0.019) for {'max_leaf_nodes': 60, 'min_samples_split': 25}
# 0.748 (+/-0.035) for {'max_leaf_nodes': 60, 'min_samples_split': 30}
# 0.754 (+/-0.038) for {'max_leaf_nodes': 60, 'min_samples_split': 35}
# 0.753 (+/-0.033) for {'max_leaf_nodes': 60, 'min_samples_split': 40}
# 0.754 (+/-0.033) for {'max_leaf_nodes': 60, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 60, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 60, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 60, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 60, 'min_samples_split': 65}
# 0.760 (+/-0.020) for {'max_leaf_nodes': 60, 'min_samples_split': 70}
# 0.767 (+/-0.021) for {'max_leaf_nodes': 60, 'min_samples_split': 75}
# 0.731 (+/-0.027) for {'max_leaf_nodes': 65, 'min_samples_split': 5}
# 0.730 (+/-0.022) for {'max_leaf_nodes': 65, 'min_samples_split': 10}
# 0.736 (+/-0.036) for {'max_leaf_nodes': 65, 'min_samples_split': 15}
# 0.739 (+/-0.020) for {'max_leaf_nodes': 65, 'min_samples_split': 20}
# 0.756 (+/-0.022) for {'max_leaf_nodes': 65, 'min_samples_split': 25}
# 0.750 (+/-0.027) for {'max_leaf_nodes': 65, 'min_samples_split': 30}
# 0.756 (+/-0.030) for {'max_leaf_nodes': 65, 'min_samples_split': 35}
# 0.757 (+/-0.028) for {'max_leaf_nodes': 65, 'min_samples_split': 40}
# 0.754 (+/-0.033) for {'max_leaf_nodes': 65, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 65, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 65, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 65, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 65, 'min_samples_split': 65}
# 0.758 (+/-0.023) for {'max_leaf_nodes': 65, 'min_samples_split': 70}
# 0.767 (+/-0.021) for {'max_leaf_nodes': 65, 'min_samples_split': 75}
# 0.729 (+/-0.023) for {'max_leaf_nodes': 70, 'min_samples_split': 5}
# 0.736 (+/-0.022) for {'max_leaf_nodes': 70, 'min_samples_split': 10}
# 0.733 (+/-0.033) for {'max_leaf_nodes': 70, 'min_samples_split': 15}
# 0.739 (+/-0.017) for {'max_leaf_nodes': 70, 'min_samples_split': 20}
# 0.752 (+/-0.028) for {'max_leaf_nodes': 70, 'min_samples_split': 25}
# 0.750 (+/-0.027) for {'max_leaf_nodes': 70, 'min_samples_split': 30}
# 0.749 (+/-0.035) for {'max_leaf_nodes': 70, 'min_samples_split': 35}
# 0.757 (+/-0.028) for {'max_leaf_nodes': 70, 'min_samples_split': 40}
# 0.754 (+/-0.033) for {'max_leaf_nodes': 70, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 70, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 70, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 70, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 70, 'min_samples_split': 65}
# 0.758 (+/-0.023) for {'max_leaf_nodes': 70, 'min_samples_split': 70}
# 0.767 (+/-0.021) for {'max_leaf_nodes': 70, 'min_samples_split': 75}
# 0.730 (+/-0.030) for {'max_leaf_nodes': 75, 'min_samples_split': 5}
# 0.725 (+/-0.030) for {'max_leaf_nodes': 75, 'min_samples_split': 10}
# 0.736 (+/-0.035) for {'max_leaf_nodes': 75, 'min_samples_split': 15}
# 0.741 (+/-0.024) for {'max_leaf_nodes': 75, 'min_samples_split': 20}
# 0.758 (+/-0.020) for {'max_leaf_nodes': 75, 'min_samples_split': 25}
# 0.750 (+/-0.036) for {'max_leaf_nodes': 75, 'min_samples_split': 30}
# 0.752 (+/-0.036) for {'max_leaf_nodes': 75, 'min_samples_split': 35}
# 0.753 (+/-0.033) for {'max_leaf_nodes': 75, 'min_samples_split': 40}
# 0.754 (+/-0.033) for {'max_leaf_nodes': 75, 'min_samples_split': 45}
# 0.756 (+/-0.031) for {'max_leaf_nodes': 75, 'min_samples_split': 50}
# 0.753 (+/-0.029) for {'max_leaf_nodes': 75, 'min_samples_split': 55}
# 0.748 (+/-0.024) for {'max_leaf_nodes': 75, 'min_samples_split': 60}
# 0.755 (+/-0.019) for {'max_leaf_nodes': 75, 'min_samples_split': 65}
# 0.760 (+/-0.020) for {'max_leaf_nodes': 75, 'min_samples_split': 70}
# 0.764 (+/-0.019) for {'max_leaf_nodes': 75, 'min_samples_split': 75}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.95      0.84       259
#          1.0       0.78      0.38      0.51       125
#
#     accuracy                           0.76       384
#    macro avg       0.77      0.66      0.68       384
# weighted avg       0.77      0.76      0.73       384
#
#
# Testing score:  0.7346000320646547
#
# Training Score:  0.7880291177920639

# %% [markdown]
# # With SMOTE Oversampling

# %%
X_train = np.load('Data/X_train_smote.npy', allow_pickle= True)
y_train = np.load('Data/Y_train_smote.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 1202 1202 384 384

# %%
from sklearn.tree import DecisionTreeClassifier #import the DT classifier


tuned_parameters = [{'min_samples_split': [i for i in range(5,80,5)], 'max_leaf_nodes':  [k for k in range(5,80,5)]}]

clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'max_leaf_nodes': 35, 'min_samples_split': 10}
#
#  Best Score 0.8045755476392245
#
#  Grid scores on development set:
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 5}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 10}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 15}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 20}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 25}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 30}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 35}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 40}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 45}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 50}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 55}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 60}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 65}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 70}
# 0.729 (+/-0.097) for {'max_leaf_nodes': 5, 'min_samples_split': 75}
# 0.736 (+/-0.084) for {'max_leaf_nodes': 10, 'min_samples_split': 5}
# 0.736 (+/-0.084) for {'max_leaf_nodes': 10, 'min_samples_split': 10}
# 0.736 (+/-0.084) for {'max_leaf_nodes': 10, 'min_samples_split': 15}
# 0.736 (+/-0.084) for {'max_leaf_nodes': 10, 'min_samples_split': 20}
# 0.736 (+/-0.084) for {'max_leaf_nodes': 10, 'min_samples_split': 25}
# 0.744 (+/-0.072) for {'max_leaf_nodes': 10, 'min_samples_split': 30}
# 0.744 (+/-0.072) for {'max_leaf_nodes': 10, 'min_samples_split': 35}
# 0.744 (+/-0.072) for {'max_leaf_nodes': 10, 'min_samples_split': 40}
# 0.744 (+/-0.072) for {'max_leaf_nodes': 10, 'min_samples_split': 45}
# 0.744 (+/-0.072) for {'max_leaf_nodes': 10, 'min_samples_split': 50}
# 0.744 (+/-0.072) for {'max_leaf_nodes': 10, 'min_samples_split': 55}
# 0.746 (+/-0.070) for {'max_leaf_nodes': 10, 'min_samples_split': 60}
# 0.746 (+/-0.070) for {'max_leaf_nodes': 10, 'min_samples_split': 65}
# 0.746 (+/-0.070) for {'max_leaf_nodes': 10, 'min_samples_split': 70}
# 0.746 (+/-0.070) for {'max_leaf_nodes': 10, 'min_samples_split': 75}
# 0.764 (+/-0.081) for {'max_leaf_nodes': 15, 'min_samples_split': 5}
# 0.764 (+/-0.081) for {'max_leaf_nodes': 15, 'min_samples_split': 10}
# 0.764 (+/-0.081) for {'max_leaf_nodes': 15, 'min_samples_split': 15}
# 0.764 (+/-0.081) for {'max_leaf_nodes': 15, 'min_samples_split': 20}
# 0.764 (+/-0.081) for {'max_leaf_nodes': 15, 'min_samples_split': 25}
# 0.764 (+/-0.081) for {'max_leaf_nodes': 15, 'min_samples_split': 30}
# 0.775 (+/-0.070) for {'max_leaf_nodes': 15, 'min_samples_split': 35}
# 0.774 (+/-0.071) for {'max_leaf_nodes': 15, 'min_samples_split': 40}
# 0.776 (+/-0.073) for {'max_leaf_nodes': 15, 'min_samples_split': 45}
# 0.776 (+/-0.072) for {'max_leaf_nodes': 15, 'min_samples_split': 50}
# 0.776 (+/-0.072) for {'max_leaf_nodes': 15, 'min_samples_split': 55}
# 0.776 (+/-0.072) for {'max_leaf_nodes': 15, 'min_samples_split': 60}
# 0.776 (+/-0.072) for {'max_leaf_nodes': 15, 'min_samples_split': 65}
# 0.776 (+/-0.067) for {'max_leaf_nodes': 15, 'min_samples_split': 70}
# 0.777 (+/-0.067) for {'max_leaf_nodes': 15, 'min_samples_split': 75}
# 0.771 (+/-0.074) for {'max_leaf_nodes': 20, 'min_samples_split': 5}
# 0.771 (+/-0.074) for {'max_leaf_nodes': 20, 'min_samples_split': 10}
# 0.771 (+/-0.074) for {'max_leaf_nodes': 20, 'min_samples_split': 15}
# 0.772 (+/-0.073) for {'max_leaf_nodes': 20, 'min_samples_split': 20}
# 0.771 (+/-0.073) for {'max_leaf_nodes': 20, 'min_samples_split': 25}
# 0.768 (+/-0.072) for {'max_leaf_nodes': 20, 'min_samples_split': 30}
# 0.773 (+/-0.077) for {'max_leaf_nodes': 20, 'min_samples_split': 35}
# 0.772 (+/-0.078) for {'max_leaf_nodes': 20, 'min_samples_split': 40}
# 0.774 (+/-0.081) for {'max_leaf_nodes': 20, 'min_samples_split': 45}
# 0.788 (+/-0.065) for {'max_leaf_nodes': 20, 'min_samples_split': 50}
# 0.789 (+/-0.063) for {'max_leaf_nodes': 20, 'min_samples_split': 55}
# 0.786 (+/-0.073) for {'max_leaf_nodes': 20, 'min_samples_split': 60}
# 0.786 (+/-0.073) for {'max_leaf_nodes': 20, 'min_samples_split': 65}
# 0.787 (+/-0.068) for {'max_leaf_nodes': 20, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 20, 'min_samples_split': 75}
# 0.782 (+/-0.081) for {'max_leaf_nodes': 25, 'min_samples_split': 5}
# 0.784 (+/-0.075) for {'max_leaf_nodes': 25, 'min_samples_split': 10}
# 0.784 (+/-0.073) for {'max_leaf_nodes': 25, 'min_samples_split': 15}
# 0.784 (+/-0.070) for {'max_leaf_nodes': 25, 'min_samples_split': 20}
# 0.783 (+/-0.077) for {'max_leaf_nodes': 25, 'min_samples_split': 25}
# 0.779 (+/-0.077) for {'max_leaf_nodes': 25, 'min_samples_split': 30}
# 0.779 (+/-0.078) for {'max_leaf_nodes': 25, 'min_samples_split': 35}
# 0.784 (+/-0.071) for {'max_leaf_nodes': 25, 'min_samples_split': 40}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 25, 'min_samples_split': 45}
# 0.782 (+/-0.064) for {'max_leaf_nodes': 25, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 25, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 25, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 25, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 25, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 25, 'min_samples_split': 75}
# 0.799 (+/-0.073) for {'max_leaf_nodes': 30, 'min_samples_split': 5}
# 0.802 (+/-0.068) for {'max_leaf_nodes': 30, 'min_samples_split': 10}
# 0.799 (+/-0.067) for {'max_leaf_nodes': 30, 'min_samples_split': 15}
# 0.793 (+/-0.072) for {'max_leaf_nodes': 30, 'min_samples_split': 20}
# 0.785 (+/-0.075) for {'max_leaf_nodes': 30, 'min_samples_split': 25}
# 0.777 (+/-0.077) for {'max_leaf_nodes': 30, 'min_samples_split': 30}
# 0.772 (+/-0.077) for {'max_leaf_nodes': 30, 'min_samples_split': 35}
# 0.779 (+/-0.073) for {'max_leaf_nodes': 30, 'min_samples_split': 40}
# 0.778 (+/-0.070) for {'max_leaf_nodes': 30, 'min_samples_split': 45}
# 0.783 (+/-0.065) for {'max_leaf_nodes': 30, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 30, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 30, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 30, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 30, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 30, 'min_samples_split': 75}
# 0.798 (+/-0.076) for {'max_leaf_nodes': 35, 'min_samples_split': 5}
# 0.805 (+/-0.072) for {'max_leaf_nodes': 35, 'min_samples_split': 10}
# 0.797 (+/-0.071) for {'max_leaf_nodes': 35, 'min_samples_split': 15}
# 0.789 (+/-0.070) for {'max_leaf_nodes': 35, 'min_samples_split': 20}
# 0.783 (+/-0.072) for {'max_leaf_nodes': 35, 'min_samples_split': 25}
# 0.780 (+/-0.080) for {'max_leaf_nodes': 35, 'min_samples_split': 30}
# 0.775 (+/-0.079) for {'max_leaf_nodes': 35, 'min_samples_split': 35}
# 0.779 (+/-0.073) for {'max_leaf_nodes': 35, 'min_samples_split': 40}
# 0.779 (+/-0.071) for {'max_leaf_nodes': 35, 'min_samples_split': 45}
# 0.783 (+/-0.065) for {'max_leaf_nodes': 35, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 35, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 35, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 35, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 35, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 35, 'min_samples_split': 75}
# 0.798 (+/-0.070) for {'max_leaf_nodes': 40, 'min_samples_split': 5}
# 0.797 (+/-0.070) for {'max_leaf_nodes': 40, 'min_samples_split': 10}
# 0.790 (+/-0.069) for {'max_leaf_nodes': 40, 'min_samples_split': 15}
# 0.796 (+/-0.066) for {'max_leaf_nodes': 40, 'min_samples_split': 20}
# 0.786 (+/-0.078) for {'max_leaf_nodes': 40, 'min_samples_split': 25}
# 0.778 (+/-0.079) for {'max_leaf_nodes': 40, 'min_samples_split': 30}
# 0.775 (+/-0.079) for {'max_leaf_nodes': 40, 'min_samples_split': 35}
# 0.779 (+/-0.073) for {'max_leaf_nodes': 40, 'min_samples_split': 40}
# 0.778 (+/-0.070) for {'max_leaf_nodes': 40, 'min_samples_split': 45}
# 0.782 (+/-0.064) for {'max_leaf_nodes': 40, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 40, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 40, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 40, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 40, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 40, 'min_samples_split': 75}
# 0.801 (+/-0.069) for {'max_leaf_nodes': 45, 'min_samples_split': 5}
# 0.795 (+/-0.068) for {'max_leaf_nodes': 45, 'min_samples_split': 10}
# 0.800 (+/-0.068) for {'max_leaf_nodes': 45, 'min_samples_split': 15}
# 0.795 (+/-0.069) for {'max_leaf_nodes': 45, 'min_samples_split': 20}
# 0.785 (+/-0.078) for {'max_leaf_nodes': 45, 'min_samples_split': 25}
# 0.781 (+/-0.081) for {'max_leaf_nodes': 45, 'min_samples_split': 30}
# 0.776 (+/-0.080) for {'max_leaf_nodes': 45, 'min_samples_split': 35}
# 0.779 (+/-0.073) for {'max_leaf_nodes': 45, 'min_samples_split': 40}
# 0.779 (+/-0.071) for {'max_leaf_nodes': 45, 'min_samples_split': 45}
# 0.783 (+/-0.065) for {'max_leaf_nodes': 45, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 45, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 45, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 45, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 45, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 45, 'min_samples_split': 75}
# 0.793 (+/-0.072) for {'max_leaf_nodes': 50, 'min_samples_split': 5}
# 0.800 (+/-0.065) for {'max_leaf_nodes': 50, 'min_samples_split': 10}
# 0.802 (+/-0.071) for {'max_leaf_nodes': 50, 'min_samples_split': 15}
# 0.796 (+/-0.069) for {'max_leaf_nodes': 50, 'min_samples_split': 20}
# 0.785 (+/-0.078) for {'max_leaf_nodes': 50, 'min_samples_split': 25}
# 0.778 (+/-0.077) for {'max_leaf_nodes': 50, 'min_samples_split': 30}
# 0.776 (+/-0.080) for {'max_leaf_nodes': 50, 'min_samples_split': 35}
# 0.778 (+/-0.072) for {'max_leaf_nodes': 50, 'min_samples_split': 40}
# 0.779 (+/-0.071) for {'max_leaf_nodes': 50, 'min_samples_split': 45}
# 0.783 (+/-0.065) for {'max_leaf_nodes': 50, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 50, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 50, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 50, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 50, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 50, 'min_samples_split': 75}
# 0.793 (+/-0.071) for {'max_leaf_nodes': 55, 'min_samples_split': 5}
# 0.793 (+/-0.065) for {'max_leaf_nodes': 55, 'min_samples_split': 10}
# 0.800 (+/-0.067) for {'max_leaf_nodes': 55, 'min_samples_split': 15}
# 0.797 (+/-0.069) for {'max_leaf_nodes': 55, 'min_samples_split': 20}
# 0.784 (+/-0.077) for {'max_leaf_nodes': 55, 'min_samples_split': 25}
# 0.782 (+/-0.081) for {'max_leaf_nodes': 55, 'min_samples_split': 30}
# 0.775 (+/-0.079) for {'max_leaf_nodes': 55, 'min_samples_split': 35}
# 0.780 (+/-0.074) for {'max_leaf_nodes': 55, 'min_samples_split': 40}
# 0.779 (+/-0.071) for {'max_leaf_nodes': 55, 'min_samples_split': 45}
# 0.783 (+/-0.065) for {'max_leaf_nodes': 55, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 55, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 55, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 55, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 55, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 55, 'min_samples_split': 75}
# 0.791 (+/-0.068) for {'max_leaf_nodes': 60, 'min_samples_split': 5}
# 0.798 (+/-0.063) for {'max_leaf_nodes': 60, 'min_samples_split': 10}
# 0.798 (+/-0.067) for {'max_leaf_nodes': 60, 'min_samples_split': 15}
# 0.792 (+/-0.069) for {'max_leaf_nodes': 60, 'min_samples_split': 20}
# 0.787 (+/-0.079) for {'max_leaf_nodes': 60, 'min_samples_split': 25}
# 0.777 (+/-0.077) for {'max_leaf_nodes': 60, 'min_samples_split': 30}
# 0.775 (+/-0.079) for {'max_leaf_nodes': 60, 'min_samples_split': 35}
# 0.778 (+/-0.072) for {'max_leaf_nodes': 60, 'min_samples_split': 40}
# 0.779 (+/-0.071) for {'max_leaf_nodes': 60, 'min_samples_split': 45}
# 0.782 (+/-0.064) for {'max_leaf_nodes': 60, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 60, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 60, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 60, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 60, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 60, 'min_samples_split': 75}
# 0.800 (+/-0.063) for {'max_leaf_nodes': 65, 'min_samples_split': 5}
# 0.797 (+/-0.067) for {'max_leaf_nodes': 65, 'min_samples_split': 10}
# 0.802 (+/-0.071) for {'max_leaf_nodes': 65, 'min_samples_split': 15}
# 0.799 (+/-0.072) for {'max_leaf_nodes': 65, 'min_samples_split': 20}
# 0.785 (+/-0.077) for {'max_leaf_nodes': 65, 'min_samples_split': 25}
# 0.776 (+/-0.076) for {'max_leaf_nodes': 65, 'min_samples_split': 30}
# 0.775 (+/-0.079) for {'max_leaf_nodes': 65, 'min_samples_split': 35}
# 0.779 (+/-0.073) for {'max_leaf_nodes': 65, 'min_samples_split': 40}
# 0.779 (+/-0.071) for {'max_leaf_nodes': 65, 'min_samples_split': 45}
# 0.782 (+/-0.064) for {'max_leaf_nodes': 65, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 65, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 65, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 65, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 65, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 65, 'min_samples_split': 75}
# 0.800 (+/-0.067) for {'max_leaf_nodes': 70, 'min_samples_split': 5}
# 0.800 (+/-0.071) for {'max_leaf_nodes': 70, 'min_samples_split': 10}
# 0.802 (+/-0.071) for {'max_leaf_nodes': 70, 'min_samples_split': 15}
# 0.797 (+/-0.071) for {'max_leaf_nodes': 70, 'min_samples_split': 20}
# 0.786 (+/-0.078) for {'max_leaf_nodes': 70, 'min_samples_split': 25}
# 0.778 (+/-0.078) for {'max_leaf_nodes': 70, 'min_samples_split': 30}
# 0.776 (+/-0.080) for {'max_leaf_nodes': 70, 'min_samples_split': 35}
# 0.778 (+/-0.072) for {'max_leaf_nodes': 70, 'min_samples_split': 40}
# 0.779 (+/-0.071) for {'max_leaf_nodes': 70, 'min_samples_split': 45}
# 0.782 (+/-0.064) for {'max_leaf_nodes': 70, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 70, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 70, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 70, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 70, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 70, 'min_samples_split': 75}
# 0.803 (+/-0.071) for {'max_leaf_nodes': 75, 'min_samples_split': 5}
# 0.802 (+/-0.072) for {'max_leaf_nodes': 75, 'min_samples_split': 10}
# 0.798 (+/-0.068) for {'max_leaf_nodes': 75, 'min_samples_split': 15}
# 0.795 (+/-0.068) for {'max_leaf_nodes': 75, 'min_samples_split': 20}
# 0.786 (+/-0.078) for {'max_leaf_nodes': 75, 'min_samples_split': 25}
# 0.778 (+/-0.077) for {'max_leaf_nodes': 75, 'min_samples_split': 30}
# 0.775 (+/-0.079) for {'max_leaf_nodes': 75, 'min_samples_split': 35}
# 0.779 (+/-0.073) for {'max_leaf_nodes': 75, 'min_samples_split': 40}
# 0.778 (+/-0.070) for {'max_leaf_nodes': 75, 'min_samples_split': 45}
# 0.782 (+/-0.064) for {'max_leaf_nodes': 75, 'min_samples_split': 50}
# 0.789 (+/-0.066) for {'max_leaf_nodes': 75, 'min_samples_split': 55}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 75, 'min_samples_split': 60}
# 0.786 (+/-0.075) for {'max_leaf_nodes': 75, 'min_samples_split': 65}
# 0.787 (+/-0.070) for {'max_leaf_nodes': 75, 'min_samples_split': 70}
# 0.782 (+/-0.073) for {'max_leaf_nodes': 75, 'min_samples_split': 75}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.93      0.86       259
#          1.0       0.77      0.50      0.61       125
#
#     accuracy                           0.79       384
#    macro avg       0.78      0.72      0.73       384
# weighted avg       0.79      0.79      0.78       384
#
#
# Testing score:  0.7752375900953267
#
# Training Score:  0.8780736565953

# %% [markdown]
# # With Borderline-SMOTE Oversampling

# %%
X_train = np.load('Data/X_train_borderline_smote.npy', allow_pickle= True)
y_train = np.load('Data/Y_train_borderline_smote.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 1202 1202 384 384

# %%
from sklearn.tree import DecisionTreeClassifier #import the DT classifier


tuned_parameters = [{'min_samples_split': [i for i in range(5,80,5)], 'max_leaf_nodes':  [k for k in range(5,80,5)]}]

clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'max_leaf_nodes': 30, 'min_samples_split': 10}
#
#  Best Score 0.7965890031741519
#
#  Grid scores on development set:
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 5}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 10}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 15}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 20}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 25}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 30}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 35}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 40}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 45}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 50}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 55}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 60}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 65}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 70}
# 0.737 (+/-0.043) for {'max_leaf_nodes': 5, 'min_samples_split': 75}
# 0.765 (+/-0.048) for {'max_leaf_nodes': 10, 'min_samples_split': 5}
# 0.766 (+/-0.049) for {'max_leaf_nodes': 10, 'min_samples_split': 10}
# 0.765 (+/-0.048) for {'max_leaf_nodes': 10, 'min_samples_split': 15}
# 0.765 (+/-0.048) for {'max_leaf_nodes': 10, 'min_samples_split': 20}
# 0.766 (+/-0.049) for {'max_leaf_nodes': 10, 'min_samples_split': 25}
# 0.765 (+/-0.048) for {'max_leaf_nodes': 10, 'min_samples_split': 30}
# 0.766 (+/-0.049) for {'max_leaf_nodes': 10, 'min_samples_split': 35}
# 0.766 (+/-0.049) for {'max_leaf_nodes': 10, 'min_samples_split': 40}
# 0.765 (+/-0.048) for {'max_leaf_nodes': 10, 'min_samples_split': 45}
# 0.766 (+/-0.049) for {'max_leaf_nodes': 10, 'min_samples_split': 50}
# 0.765 (+/-0.048) for {'max_leaf_nodes': 10, 'min_samples_split': 55}
# 0.759 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 60}
# 0.760 (+/-0.056) for {'max_leaf_nodes': 10, 'min_samples_split': 65}
# 0.760 (+/-0.056) for {'max_leaf_nodes': 10, 'min_samples_split': 70}
# 0.759 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 75}
# 0.767 (+/-0.068) for {'max_leaf_nodes': 15, 'min_samples_split': 5}
# 0.767 (+/-0.068) for {'max_leaf_nodes': 15, 'min_samples_split': 10}
# 0.770 (+/-0.070) for {'max_leaf_nodes': 15, 'min_samples_split': 15}
# 0.770 (+/-0.070) for {'max_leaf_nodes': 15, 'min_samples_split': 20}
# 0.772 (+/-0.069) for {'max_leaf_nodes': 15, 'min_samples_split': 25}
# 0.767 (+/-0.066) for {'max_leaf_nodes': 15, 'min_samples_split': 30}
# 0.765 (+/-0.068) for {'max_leaf_nodes': 15, 'min_samples_split': 35}
# 0.769 (+/-0.070) for {'max_leaf_nodes': 15, 'min_samples_split': 40}
# 0.765 (+/-0.068) for {'max_leaf_nodes': 15, 'min_samples_split': 45}
# 0.765 (+/-0.068) for {'max_leaf_nodes': 15, 'min_samples_split': 50}
# 0.763 (+/-0.066) for {'max_leaf_nodes': 15, 'min_samples_split': 55}
# 0.766 (+/-0.061) for {'max_leaf_nodes': 15, 'min_samples_split': 60}
# 0.769 (+/-0.066) for {'max_leaf_nodes': 15, 'min_samples_split': 65}
# 0.768 (+/-0.065) for {'max_leaf_nodes': 15, 'min_samples_split': 70}
# 0.773 (+/-0.064) for {'max_leaf_nodes': 15, 'min_samples_split': 75}
# 0.766 (+/-0.084) for {'max_leaf_nodes': 20, 'min_samples_split': 5}
# 0.766 (+/-0.084) for {'max_leaf_nodes': 20, 'min_samples_split': 10}
# 0.768 (+/-0.083) for {'max_leaf_nodes': 20, 'min_samples_split': 15}
# 0.768 (+/-0.080) for {'max_leaf_nodes': 20, 'min_samples_split': 20}
# 0.767 (+/-0.080) for {'max_leaf_nodes': 20, 'min_samples_split': 25}
# 0.770 (+/-0.082) for {'max_leaf_nodes': 20, 'min_samples_split': 30}
# 0.770 (+/-0.075) for {'max_leaf_nodes': 20, 'min_samples_split': 35}
# 0.778 (+/-0.070) for {'max_leaf_nodes': 20, 'min_samples_split': 40}
# 0.773 (+/-0.076) for {'max_leaf_nodes': 20, 'min_samples_split': 45}
# 0.778 (+/-0.076) for {'max_leaf_nodes': 20, 'min_samples_split': 50}
# 0.774 (+/-0.072) for {'max_leaf_nodes': 20, 'min_samples_split': 55}
# 0.779 (+/-0.067) for {'max_leaf_nodes': 20, 'min_samples_split': 60}
# 0.781 (+/-0.071) for {'max_leaf_nodes': 20, 'min_samples_split': 65}
# 0.780 (+/-0.070) for {'max_leaf_nodes': 20, 'min_samples_split': 70}
# 0.772 (+/-0.065) for {'max_leaf_nodes': 20, 'min_samples_split': 75}
# 0.778 (+/-0.081) for {'max_leaf_nodes': 25, 'min_samples_split': 5}
# 0.776 (+/-0.081) for {'max_leaf_nodes': 25, 'min_samples_split': 10}
# 0.775 (+/-0.082) for {'max_leaf_nodes': 25, 'min_samples_split': 15}
# 0.784 (+/-0.072) for {'max_leaf_nodes': 25, 'min_samples_split': 20}
# 0.788 (+/-0.073) for {'max_leaf_nodes': 25, 'min_samples_split': 25}
# 0.779 (+/-0.073) for {'max_leaf_nodes': 25, 'min_samples_split': 30}
# 0.782 (+/-0.069) for {'max_leaf_nodes': 25, 'min_samples_split': 35}
# 0.777 (+/-0.069) for {'max_leaf_nodes': 25, 'min_samples_split': 40}
# 0.769 (+/-0.077) for {'max_leaf_nodes': 25, 'min_samples_split': 45}
# 0.773 (+/-0.073) for {'max_leaf_nodes': 25, 'min_samples_split': 50}
# 0.773 (+/-0.071) for {'max_leaf_nodes': 25, 'min_samples_split': 55}
# 0.777 (+/-0.067) for {'max_leaf_nodes': 25, 'min_samples_split': 60}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 25, 'min_samples_split': 65}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 25, 'min_samples_split': 70}
# 0.773 (+/-0.066) for {'max_leaf_nodes': 25, 'min_samples_split': 75}
# 0.791 (+/-0.066) for {'max_leaf_nodes': 30, 'min_samples_split': 5}
# 0.797 (+/-0.062) for {'max_leaf_nodes': 30, 'min_samples_split': 10}
# 0.793 (+/-0.070) for {'max_leaf_nodes': 30, 'min_samples_split': 15}
# 0.785 (+/-0.080) for {'max_leaf_nodes': 30, 'min_samples_split': 20}
# 0.790 (+/-0.072) for {'max_leaf_nodes': 30, 'min_samples_split': 25}
# 0.776 (+/-0.071) for {'max_leaf_nodes': 30, 'min_samples_split': 30}
# 0.780 (+/-0.073) for {'max_leaf_nodes': 30, 'min_samples_split': 35}
# 0.779 (+/-0.072) for {'max_leaf_nodes': 30, 'min_samples_split': 40}
# 0.770 (+/-0.075) for {'max_leaf_nodes': 30, 'min_samples_split': 45}
# 0.773 (+/-0.073) for {'max_leaf_nodes': 30, 'min_samples_split': 50}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 30, 'min_samples_split': 55}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 30, 'min_samples_split': 60}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 30, 'min_samples_split': 65}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 30, 'min_samples_split': 70}
# 0.771 (+/-0.064) for {'max_leaf_nodes': 30, 'min_samples_split': 75}
# 0.795 (+/-0.063) for {'max_leaf_nodes': 35, 'min_samples_split': 5}
# 0.796 (+/-0.061) for {'max_leaf_nodes': 35, 'min_samples_split': 10}
# 0.794 (+/-0.065) for {'max_leaf_nodes': 35, 'min_samples_split': 15}
# 0.783 (+/-0.078) for {'max_leaf_nodes': 35, 'min_samples_split': 20}
# 0.787 (+/-0.079) for {'max_leaf_nodes': 35, 'min_samples_split': 25}
# 0.778 (+/-0.075) for {'max_leaf_nodes': 35, 'min_samples_split': 30}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 35, 'min_samples_split': 35}
# 0.778 (+/-0.071) for {'max_leaf_nodes': 35, 'min_samples_split': 40}
# 0.769 (+/-0.078) for {'max_leaf_nodes': 35, 'min_samples_split': 45}
# 0.778 (+/-0.077) for {'max_leaf_nodes': 35, 'min_samples_split': 50}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 35, 'min_samples_split': 55}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 35, 'min_samples_split': 60}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 35, 'min_samples_split': 65}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 35, 'min_samples_split': 70}
# 0.773 (+/-0.066) for {'max_leaf_nodes': 35, 'min_samples_split': 75}
# 0.791 (+/-0.063) for {'max_leaf_nodes': 40, 'min_samples_split': 5}
# 0.795 (+/-0.064) for {'max_leaf_nodes': 40, 'min_samples_split': 10}
# 0.789 (+/-0.065) for {'max_leaf_nodes': 40, 'min_samples_split': 15}
# 0.780 (+/-0.078) for {'max_leaf_nodes': 40, 'min_samples_split': 20}
# 0.789 (+/-0.078) for {'max_leaf_nodes': 40, 'min_samples_split': 25}
# 0.778 (+/-0.078) for {'max_leaf_nodes': 40, 'min_samples_split': 30}
# 0.778 (+/-0.072) for {'max_leaf_nodes': 40, 'min_samples_split': 35}
# 0.778 (+/-0.075) for {'max_leaf_nodes': 40, 'min_samples_split': 40}
# 0.771 (+/-0.076) for {'max_leaf_nodes': 40, 'min_samples_split': 45}
# 0.778 (+/-0.076) for {'max_leaf_nodes': 40, 'min_samples_split': 50}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 40, 'min_samples_split': 55}
# 0.777 (+/-0.067) for {'max_leaf_nodes': 40, 'min_samples_split': 60}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 40, 'min_samples_split': 65}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 40, 'min_samples_split': 70}
# 0.773 (+/-0.066) for {'max_leaf_nodes': 40, 'min_samples_split': 75}
# 0.793 (+/-0.058) for {'max_leaf_nodes': 45, 'min_samples_split': 5}
# 0.792 (+/-0.064) for {'max_leaf_nodes': 45, 'min_samples_split': 10}
# 0.781 (+/-0.074) for {'max_leaf_nodes': 45, 'min_samples_split': 15}
# 0.779 (+/-0.082) for {'max_leaf_nodes': 45, 'min_samples_split': 20}
# 0.789 (+/-0.078) for {'max_leaf_nodes': 45, 'min_samples_split': 25}
# 0.779 (+/-0.075) for {'max_leaf_nodes': 45, 'min_samples_split': 30}
# 0.785 (+/-0.073) for {'max_leaf_nodes': 45, 'min_samples_split': 35}
# 0.780 (+/-0.076) for {'max_leaf_nodes': 45, 'min_samples_split': 40}
# 0.771 (+/-0.076) for {'max_leaf_nodes': 45, 'min_samples_split': 45}
# 0.775 (+/-0.075) for {'max_leaf_nodes': 45, 'min_samples_split': 50}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 45, 'min_samples_split': 55}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 45, 'min_samples_split': 60}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 45, 'min_samples_split': 65}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 45, 'min_samples_split': 70}
# 0.771 (+/-0.064) for {'max_leaf_nodes': 45, 'min_samples_split': 75}
# 0.791 (+/-0.064) for {'max_leaf_nodes': 50, 'min_samples_split': 5}
# 0.787 (+/-0.079) for {'max_leaf_nodes': 50, 'min_samples_split': 10}
# 0.780 (+/-0.070) for {'max_leaf_nodes': 50, 'min_samples_split': 15}
# 0.777 (+/-0.081) for {'max_leaf_nodes': 50, 'min_samples_split': 20}
# 0.790 (+/-0.080) for {'max_leaf_nodes': 50, 'min_samples_split': 25}
# 0.780 (+/-0.076) for {'max_leaf_nodes': 50, 'min_samples_split': 30}
# 0.782 (+/-0.071) for {'max_leaf_nodes': 50, 'min_samples_split': 35}
# 0.781 (+/-0.077) for {'max_leaf_nodes': 50, 'min_samples_split': 40}
# 0.774 (+/-0.082) for {'max_leaf_nodes': 50, 'min_samples_split': 45}
# 0.775 (+/-0.075) for {'max_leaf_nodes': 50, 'min_samples_split': 50}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 50, 'min_samples_split': 55}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 50, 'min_samples_split': 60}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 50, 'min_samples_split': 65}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 50, 'min_samples_split': 70}
# 0.772 (+/-0.065) for {'max_leaf_nodes': 50, 'min_samples_split': 75}
# 0.792 (+/-0.069) for {'max_leaf_nodes': 55, 'min_samples_split': 5}
# 0.786 (+/-0.067) for {'max_leaf_nodes': 55, 'min_samples_split': 10}
# 0.776 (+/-0.074) for {'max_leaf_nodes': 55, 'min_samples_split': 15}
# 0.784 (+/-0.077) for {'max_leaf_nodes': 55, 'min_samples_split': 20}
# 0.790 (+/-0.078) for {'max_leaf_nodes': 55, 'min_samples_split': 25}
# 0.777 (+/-0.077) for {'max_leaf_nodes': 55, 'min_samples_split': 30}
# 0.780 (+/-0.073) for {'max_leaf_nodes': 55, 'min_samples_split': 35}
# 0.778 (+/-0.075) for {'max_leaf_nodes': 55, 'min_samples_split': 40}
# 0.771 (+/-0.079) for {'max_leaf_nodes': 55, 'min_samples_split': 45}
# 0.778 (+/-0.077) for {'max_leaf_nodes': 55, 'min_samples_split': 50}
# 0.773 (+/-0.071) for {'max_leaf_nodes': 55, 'min_samples_split': 55}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 55, 'min_samples_split': 60}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 55, 'min_samples_split': 65}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 55, 'min_samples_split': 70}
# 0.772 (+/-0.065) for {'max_leaf_nodes': 55, 'min_samples_split': 75}
# 0.784 (+/-0.069) for {'max_leaf_nodes': 60, 'min_samples_split': 5}
# 0.783 (+/-0.083) for {'max_leaf_nodes': 60, 'min_samples_split': 10}
# 0.776 (+/-0.078) for {'max_leaf_nodes': 60, 'min_samples_split': 15}
# 0.782 (+/-0.080) for {'max_leaf_nodes': 60, 'min_samples_split': 20}
# 0.787 (+/-0.077) for {'max_leaf_nodes': 60, 'min_samples_split': 25}
# 0.781 (+/-0.076) for {'max_leaf_nodes': 60, 'min_samples_split': 30}
# 0.781 (+/-0.070) for {'max_leaf_nodes': 60, 'min_samples_split': 35}
# 0.782 (+/-0.074) for {'max_leaf_nodes': 60, 'min_samples_split': 40}
# 0.774 (+/-0.082) for {'max_leaf_nodes': 60, 'min_samples_split': 45}
# 0.778 (+/-0.077) for {'max_leaf_nodes': 60, 'min_samples_split': 50}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 60, 'min_samples_split': 55}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 60, 'min_samples_split': 60}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 60, 'min_samples_split': 65}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 60, 'min_samples_split': 70}
# 0.773 (+/-0.066) for {'max_leaf_nodes': 60, 'min_samples_split': 75}
# 0.781 (+/-0.077) for {'max_leaf_nodes': 65, 'min_samples_split': 5}
# 0.775 (+/-0.077) for {'max_leaf_nodes': 65, 'min_samples_split': 10}
# 0.780 (+/-0.080) for {'max_leaf_nodes': 65, 'min_samples_split': 15}
# 0.776 (+/-0.084) for {'max_leaf_nodes': 65, 'min_samples_split': 20}
# 0.787 (+/-0.077) for {'max_leaf_nodes': 65, 'min_samples_split': 25}
# 0.780 (+/-0.079) for {'max_leaf_nodes': 65, 'min_samples_split': 30}
# 0.782 (+/-0.071) for {'max_leaf_nodes': 65, 'min_samples_split': 35}
# 0.780 (+/-0.072) for {'max_leaf_nodes': 65, 'min_samples_split': 40}
# 0.773 (+/-0.081) for {'max_leaf_nodes': 65, 'min_samples_split': 45}
# 0.778 (+/-0.076) for {'max_leaf_nodes': 65, 'min_samples_split': 50}
# 0.773 (+/-0.071) for {'max_leaf_nodes': 65, 'min_samples_split': 55}
# 0.778 (+/-0.068) for {'max_leaf_nodes': 65, 'min_samples_split': 60}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 65, 'min_samples_split': 65}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 65, 'min_samples_split': 70}
# 0.772 (+/-0.065) for {'max_leaf_nodes': 65, 'min_samples_split': 75}
# 0.781 (+/-0.082) for {'max_leaf_nodes': 70, 'min_samples_split': 5}
# 0.772 (+/-0.083) for {'max_leaf_nodes': 70, 'min_samples_split': 10}
# 0.782 (+/-0.077) for {'max_leaf_nodes': 70, 'min_samples_split': 15}
# 0.775 (+/-0.082) for {'max_leaf_nodes': 70, 'min_samples_split': 20}
# 0.786 (+/-0.079) for {'max_leaf_nodes': 70, 'min_samples_split': 25}
# 0.779 (+/-0.078) for {'max_leaf_nodes': 70, 'min_samples_split': 30}
# 0.782 (+/-0.070) for {'max_leaf_nodes': 70, 'min_samples_split': 35}
# 0.783 (+/-0.074) for {'max_leaf_nodes': 70, 'min_samples_split': 40}
# 0.771 (+/-0.079) for {'max_leaf_nodes': 70, 'min_samples_split': 45}
# 0.775 (+/-0.075) for {'max_leaf_nodes': 70, 'min_samples_split': 50}
# 0.773 (+/-0.071) for {'max_leaf_nodes': 70, 'min_samples_split': 55}
# 0.777 (+/-0.067) for {'max_leaf_nodes': 70, 'min_samples_split': 60}
# 0.780 (+/-0.071) for {'max_leaf_nodes': 70, 'min_samples_split': 65}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 70, 'min_samples_split': 70}
# 0.771 (+/-0.064) for {'max_leaf_nodes': 70, 'min_samples_split': 75}
# 0.780 (+/-0.083) for {'max_leaf_nodes': 75, 'min_samples_split': 5}
# 0.774 (+/-0.081) for {'max_leaf_nodes': 75, 'min_samples_split': 10}
# 0.774 (+/-0.075) for {'max_leaf_nodes': 75, 'min_samples_split': 15}
# 0.782 (+/-0.076) for {'max_leaf_nodes': 75, 'min_samples_split': 20}
# 0.788 (+/-0.078) for {'max_leaf_nodes': 75, 'min_samples_split': 25}
# 0.778 (+/-0.074) for {'max_leaf_nodes': 75, 'min_samples_split': 30}
# 0.782 (+/-0.071) for {'max_leaf_nodes': 75, 'min_samples_split': 35}
# 0.778 (+/-0.075) for {'max_leaf_nodes': 75, 'min_samples_split': 40}
# 0.771 (+/-0.079) for {'max_leaf_nodes': 75, 'min_samples_split': 45}
# 0.775 (+/-0.075) for {'max_leaf_nodes': 75, 'min_samples_split': 50}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 75, 'min_samples_split': 55}
# 0.777 (+/-0.067) for {'max_leaf_nodes': 75, 'min_samples_split': 60}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 75, 'min_samples_split': 65}
# 0.779 (+/-0.070) for {'max_leaf_nodes': 75, 'min_samples_split': 70}
# 0.773 (+/-0.066) for {'max_leaf_nodes': 75, 'min_samples_split': 75}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.86      0.82       259
#          1.0       0.63      0.50      0.56       125
#
#     accuracy                           0.74       384
#    macro avg       0.71      0.68      0.69       384
# weighted avg       0.73      0.74      0.73       384
#
#
# Testing score:  0.7329661980088039
#
# Training Score:  0.8725002651824767

# %% [markdown]
# # With ADASYN Oversampling

# %%
X_train = np.load('Data/X_train_adasyn.npy', allow_pickle= True)
y_train = np.load('Data/Y_train_adasyn.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 1168 1168 384 384

# %%
from sklearn.tree import DecisionTreeClassifier #import the DT classifier


tuned_parameters = [{'min_samples_split': [i for i in range(5,80,5)], 'max_leaf_nodes':  [k for k in range(5,80,5)]}]

clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'max_leaf_nodes': 35, 'min_samples_split': 30}
#
#  Best Score 0.7849579039707048
#
#  Grid scores on development set:
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 5}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 10}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 15}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 20}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 25}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 30}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 35}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 40}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 45}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 50}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 55}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 60}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 65}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 70}
# 0.724 (+/-0.060) for {'max_leaf_nodes': 5, 'min_samples_split': 75}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 5}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 10}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 15}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 20}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 25}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 30}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 35}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 40}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 45}
# 0.727 (+/-0.055) for {'max_leaf_nodes': 10, 'min_samples_split': 50}
# 0.719 (+/-0.047) for {'max_leaf_nodes': 10, 'min_samples_split': 55}
# 0.721 (+/-0.045) for {'max_leaf_nodes': 10, 'min_samples_split': 60}
# 0.721 (+/-0.045) for {'max_leaf_nodes': 10, 'min_samples_split': 65}
# 0.721 (+/-0.045) for {'max_leaf_nodes': 10, 'min_samples_split': 70}
# 0.721 (+/-0.045) for {'max_leaf_nodes': 10, 'min_samples_split': 75}
# 0.737 (+/-0.050) for {'max_leaf_nodes': 15, 'min_samples_split': 5}
# 0.737 (+/-0.050) for {'max_leaf_nodes': 15, 'min_samples_split': 10}
# 0.737 (+/-0.050) for {'max_leaf_nodes': 15, 'min_samples_split': 15}
# 0.737 (+/-0.050) for {'max_leaf_nodes': 15, 'min_samples_split': 20}
# 0.737 (+/-0.050) for {'max_leaf_nodes': 15, 'min_samples_split': 25}
# 0.738 (+/-0.048) for {'max_leaf_nodes': 15, 'min_samples_split': 30}
# 0.743 (+/-0.049) for {'max_leaf_nodes': 15, 'min_samples_split': 35}
# 0.737 (+/-0.047) for {'max_leaf_nodes': 15, 'min_samples_split': 40}
# 0.734 (+/-0.050) for {'max_leaf_nodes': 15, 'min_samples_split': 45}
# 0.734 (+/-0.050) for {'max_leaf_nodes': 15, 'min_samples_split': 50}
# 0.735 (+/-0.039) for {'max_leaf_nodes': 15, 'min_samples_split': 55}
# 0.734 (+/-0.037) for {'max_leaf_nodes': 15, 'min_samples_split': 60}
# 0.734 (+/-0.037) for {'max_leaf_nodes': 15, 'min_samples_split': 65}
# 0.733 (+/-0.039) for {'max_leaf_nodes': 15, 'min_samples_split': 70}
# 0.735 (+/-0.036) for {'max_leaf_nodes': 15, 'min_samples_split': 75}
# 0.758 (+/-0.059) for {'max_leaf_nodes': 20, 'min_samples_split': 5}
# 0.758 (+/-0.059) for {'max_leaf_nodes': 20, 'min_samples_split': 10}
# 0.759 (+/-0.058) for {'max_leaf_nodes': 20, 'min_samples_split': 15}
# 0.757 (+/-0.057) for {'max_leaf_nodes': 20, 'min_samples_split': 20}
# 0.758 (+/-0.058) for {'max_leaf_nodes': 20, 'min_samples_split': 25}
# 0.766 (+/-0.049) for {'max_leaf_nodes': 20, 'min_samples_split': 30}
# 0.766 (+/-0.047) for {'max_leaf_nodes': 20, 'min_samples_split': 35}
# 0.762 (+/-0.046) for {'max_leaf_nodes': 20, 'min_samples_split': 40}
# 0.761 (+/-0.052) for {'max_leaf_nodes': 20, 'min_samples_split': 45}
# 0.761 (+/-0.052) for {'max_leaf_nodes': 20, 'min_samples_split': 50}
# 0.748 (+/-0.041) for {'max_leaf_nodes': 20, 'min_samples_split': 55}
# 0.744 (+/-0.048) for {'max_leaf_nodes': 20, 'min_samples_split': 60}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 20, 'min_samples_split': 65}
# 0.746 (+/-0.046) for {'max_leaf_nodes': 20, 'min_samples_split': 70}
# 0.748 (+/-0.043) for {'max_leaf_nodes': 20, 'min_samples_split': 75}
# 0.768 (+/-0.054) for {'max_leaf_nodes': 25, 'min_samples_split': 5}
# 0.765 (+/-0.053) for {'max_leaf_nodes': 25, 'min_samples_split': 10}
# 0.767 (+/-0.051) for {'max_leaf_nodes': 25, 'min_samples_split': 15}
# 0.768 (+/-0.050) for {'max_leaf_nodes': 25, 'min_samples_split': 20}
# 0.766 (+/-0.051) for {'max_leaf_nodes': 25, 'min_samples_split': 25}
# 0.771 (+/-0.059) for {'max_leaf_nodes': 25, 'min_samples_split': 30}
# 0.773 (+/-0.054) for {'max_leaf_nodes': 25, 'min_samples_split': 35}
# 0.771 (+/-0.054) for {'max_leaf_nodes': 25, 'min_samples_split': 40}
# 0.771 (+/-0.062) for {'max_leaf_nodes': 25, 'min_samples_split': 45}
# 0.768 (+/-0.061) for {'max_leaf_nodes': 25, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 25, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 25, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 25, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 25, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 25, 'min_samples_split': 75}
# 0.764 (+/-0.062) for {'max_leaf_nodes': 30, 'min_samples_split': 5}
# 0.765 (+/-0.064) for {'max_leaf_nodes': 30, 'min_samples_split': 10}
# 0.764 (+/-0.060) for {'max_leaf_nodes': 30, 'min_samples_split': 15}
# 0.762 (+/-0.061) for {'max_leaf_nodes': 30, 'min_samples_split': 20}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 30, 'min_samples_split': 25}
# 0.783 (+/-0.065) for {'max_leaf_nodes': 30, 'min_samples_split': 30}
# 0.779 (+/-0.065) for {'max_leaf_nodes': 30, 'min_samples_split': 35}
# 0.776 (+/-0.060) for {'max_leaf_nodes': 30, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 30, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 30, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 30, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 30, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 30, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 30, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 30, 'min_samples_split': 75}
# 0.769 (+/-0.066) for {'max_leaf_nodes': 35, 'min_samples_split': 5}
# 0.758 (+/-0.072) for {'max_leaf_nodes': 35, 'min_samples_split': 10}
# 0.770 (+/-0.069) for {'max_leaf_nodes': 35, 'min_samples_split': 15}
# 0.771 (+/-0.072) for {'max_leaf_nodes': 35, 'min_samples_split': 20}
# 0.779 (+/-0.062) for {'max_leaf_nodes': 35, 'min_samples_split': 25}
# 0.785 (+/-0.067) for {'max_leaf_nodes': 35, 'min_samples_split': 30}
# 0.783 (+/-0.062) for {'max_leaf_nodes': 35, 'min_samples_split': 35}
# 0.776 (+/-0.059) for {'max_leaf_nodes': 35, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 35, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 35, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 35, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 35, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 35, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 35, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 35, 'min_samples_split': 75}
# 0.772 (+/-0.071) for {'max_leaf_nodes': 40, 'min_samples_split': 5}
# 0.764 (+/-0.074) for {'max_leaf_nodes': 40, 'min_samples_split': 10}
# 0.772 (+/-0.067) for {'max_leaf_nodes': 40, 'min_samples_split': 15}
# 0.771 (+/-0.071) for {'max_leaf_nodes': 40, 'min_samples_split': 20}
# 0.776 (+/-0.060) for {'max_leaf_nodes': 40, 'min_samples_split': 25}
# 0.779 (+/-0.062) for {'max_leaf_nodes': 40, 'min_samples_split': 30}
# 0.784 (+/-0.063) for {'max_leaf_nodes': 40, 'min_samples_split': 35}
# 0.776 (+/-0.060) for {'max_leaf_nodes': 40, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 40, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 40, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 40, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 40, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 40, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 40, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 40, 'min_samples_split': 75}
# 0.775 (+/-0.073) for {'max_leaf_nodes': 45, 'min_samples_split': 5}
# 0.766 (+/-0.071) for {'max_leaf_nodes': 45, 'min_samples_split': 10}
# 0.770 (+/-0.071) for {'max_leaf_nodes': 45, 'min_samples_split': 15}
# 0.766 (+/-0.071) for {'max_leaf_nodes': 45, 'min_samples_split': 20}
# 0.768 (+/-0.060) for {'max_leaf_nodes': 45, 'min_samples_split': 25}
# 0.776 (+/-0.062) for {'max_leaf_nodes': 45, 'min_samples_split': 30}
# 0.780 (+/-0.067) for {'max_leaf_nodes': 45, 'min_samples_split': 35}
# 0.776 (+/-0.059) for {'max_leaf_nodes': 45, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 45, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 45, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 45, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 45, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 45, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 45, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 45, 'min_samples_split': 75}
# 0.776 (+/-0.075) for {'max_leaf_nodes': 50, 'min_samples_split': 5}
# 0.768 (+/-0.071) for {'max_leaf_nodes': 50, 'min_samples_split': 10}
# 0.769 (+/-0.074) for {'max_leaf_nodes': 50, 'min_samples_split': 15}
# 0.764 (+/-0.062) for {'max_leaf_nodes': 50, 'min_samples_split': 20}
# 0.768 (+/-0.057) for {'max_leaf_nodes': 50, 'min_samples_split': 25}
# 0.776 (+/-0.066) for {'max_leaf_nodes': 50, 'min_samples_split': 30}
# 0.784 (+/-0.063) for {'max_leaf_nodes': 50, 'min_samples_split': 35}
# 0.776 (+/-0.059) for {'max_leaf_nodes': 50, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 50, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 50, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 50, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 50, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 50, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 50, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 50, 'min_samples_split': 75}
# 0.772 (+/-0.074) for {'max_leaf_nodes': 55, 'min_samples_split': 5}
# 0.768 (+/-0.065) for {'max_leaf_nodes': 55, 'min_samples_split': 10}
# 0.768 (+/-0.064) for {'max_leaf_nodes': 55, 'min_samples_split': 15}
# 0.763 (+/-0.065) for {'max_leaf_nodes': 55, 'min_samples_split': 20}
# 0.767 (+/-0.058) for {'max_leaf_nodes': 55, 'min_samples_split': 25}
# 0.779 (+/-0.062) for {'max_leaf_nodes': 55, 'min_samples_split': 30}
# 0.784 (+/-0.063) for {'max_leaf_nodes': 55, 'min_samples_split': 35}
# 0.776 (+/-0.059) for {'max_leaf_nodes': 55, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 55, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 55, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 55, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 55, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 55, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 55, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 55, 'min_samples_split': 75}
# 0.778 (+/-0.072) for {'max_leaf_nodes': 60, 'min_samples_split': 5}
# 0.765 (+/-0.070) for {'max_leaf_nodes': 60, 'min_samples_split': 10}
# 0.764 (+/-0.064) for {'max_leaf_nodes': 60, 'min_samples_split': 15}
# 0.756 (+/-0.065) for {'max_leaf_nodes': 60, 'min_samples_split': 20}
# 0.767 (+/-0.058) for {'max_leaf_nodes': 60, 'min_samples_split': 25}
# 0.777 (+/-0.064) for {'max_leaf_nodes': 60, 'min_samples_split': 30}
# 0.779 (+/-0.066) for {'max_leaf_nodes': 60, 'min_samples_split': 35}
# 0.776 (+/-0.060) for {'max_leaf_nodes': 60, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 60, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 60, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 60, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 60, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 60, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 60, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 60, 'min_samples_split': 75}
# 0.773 (+/-0.071) for {'max_leaf_nodes': 65, 'min_samples_split': 5}
# 0.760 (+/-0.067) for {'max_leaf_nodes': 65, 'min_samples_split': 10}
# 0.767 (+/-0.063) for {'max_leaf_nodes': 65, 'min_samples_split': 15}
# 0.758 (+/-0.063) for {'max_leaf_nodes': 65, 'min_samples_split': 20}
# 0.769 (+/-0.060) for {'max_leaf_nodes': 65, 'min_samples_split': 25}
# 0.775 (+/-0.063) for {'max_leaf_nodes': 65, 'min_samples_split': 30}
# 0.783 (+/-0.064) for {'max_leaf_nodes': 65, 'min_samples_split': 35}
# 0.776 (+/-0.060) for {'max_leaf_nodes': 65, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 65, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 65, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 65, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 65, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 65, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 65, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 65, 'min_samples_split': 75}
# 0.775 (+/-0.070) for {'max_leaf_nodes': 70, 'min_samples_split': 5}
# 0.759 (+/-0.066) for {'max_leaf_nodes': 70, 'min_samples_split': 10}
# 0.763 (+/-0.061) for {'max_leaf_nodes': 70, 'min_samples_split': 15}
# 0.763 (+/-0.064) for {'max_leaf_nodes': 70, 'min_samples_split': 20}
# 0.768 (+/-0.053) for {'max_leaf_nodes': 70, 'min_samples_split': 25}
# 0.777 (+/-0.064) for {'max_leaf_nodes': 70, 'min_samples_split': 30}
# 0.779 (+/-0.066) for {'max_leaf_nodes': 70, 'min_samples_split': 35}
# 0.776 (+/-0.059) for {'max_leaf_nodes': 70, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 70, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 70, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 70, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 70, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 70, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 70, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 70, 'min_samples_split': 75}
# 0.774 (+/-0.072) for {'max_leaf_nodes': 75, 'min_samples_split': 5}
# 0.762 (+/-0.070) for {'max_leaf_nodes': 75, 'min_samples_split': 10}
# 0.762 (+/-0.064) for {'max_leaf_nodes': 75, 'min_samples_split': 15}
# 0.763 (+/-0.062) for {'max_leaf_nodes': 75, 'min_samples_split': 20}
# 0.767 (+/-0.058) for {'max_leaf_nodes': 75, 'min_samples_split': 25}
# 0.776 (+/-0.062) for {'max_leaf_nodes': 75, 'min_samples_split': 30}
# 0.779 (+/-0.066) for {'max_leaf_nodes': 75, 'min_samples_split': 35}
# 0.776 (+/-0.060) for {'max_leaf_nodes': 75, 'min_samples_split': 40}
# 0.770 (+/-0.061) for {'max_leaf_nodes': 75, 'min_samples_split': 45}
# 0.767 (+/-0.060) for {'max_leaf_nodes': 75, 'min_samples_split': 50}
# 0.754 (+/-0.050) for {'max_leaf_nodes': 75, 'min_samples_split': 55}
# 0.751 (+/-0.055) for {'max_leaf_nodes': 75, 'min_samples_split': 60}
# 0.751 (+/-0.051) for {'max_leaf_nodes': 75, 'min_samples_split': 65}
# 0.748 (+/-0.050) for {'max_leaf_nodes': 75, 'min_samples_split': 70}
# 0.746 (+/-0.045) for {'max_leaf_nodes': 75, 'min_samples_split': 75}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.92      0.83       259
#          1.0       0.71      0.42      0.53       125
#
#     accuracy                           0.76       384
#    macro avg       0.74      0.67      0.68       384
# weighted avg       0.75      0.76      0.74       384
#
#
# Testing score:  0.7353836561032865
#
# Training Score:  0.8548803809077782
