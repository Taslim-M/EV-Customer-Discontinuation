# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pylab as pl
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc

from sklearn import datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
X_train = np.load('Data/X_train.npy', allow_pickle= True)
y_train = np.load('Data/Y_train.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 893 893 384 384

# %% [markdown]
# # K Nearest Neighbours Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier #import the KNN classifier

tuned_parameters = [{
    'n_neighbors': [i for i in range(3,31,1)], 
    'p':  [k for k in range(1,4,1)],
    'weights' : ['uniform', 'distance']
    }]
#p = 1 (manhattan_distance)
#p = 2 (euclidean_distance)
#p = 3 (minkowski_distance)
clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
#
#  Best Score 0.6872841230638213
#
#  Grid scores on development set:
# 0.655 (+/-0.011) for {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.658 (+/-0.013) for {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.624 (+/-0.024) for {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.625 (+/-0.023) for {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.638 (+/-0.030) for {'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.637 (+/-0.030) for {'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.631 (+/-0.028) for {'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
# 0.665 (+/-0.018) for {'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
# 0.621 (+/-0.025) for {'n_neighbors': 4, 'p': 2, 'weights': 'uniform'}
# 0.634 (+/-0.016) for {'n_neighbors': 4, 'p': 2, 'weights': 'distance'}
# 0.619 (+/-0.022) for {'n_neighbors': 4, 'p': 3, 'weights': 'uniform'}
# 0.632 (+/-0.024) for {'n_neighbors': 4, 'p': 3, 'weights': 'distance'}
# 0.647 (+/-0.030) for {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.648 (+/-0.030) for {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.648 (+/-0.028) for {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.651 (+/-0.028) for {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.656 (+/-0.017) for {'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.661 (+/-0.015) for {'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.626 (+/-0.034) for {'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}
# 0.666 (+/-0.019) for {'n_neighbors': 6, 'p': 1, 'weights': 'distance'}
# 0.636 (+/-0.023) for {'n_neighbors': 6, 'p': 2, 'weights': 'uniform'}
# 0.652 (+/-0.025) for {'n_neighbors': 6, 'p': 2, 'weights': 'distance'}
# 0.639 (+/-0.006) for {'n_neighbors': 6, 'p': 3, 'weights': 'uniform'}
# 0.653 (+/-0.021) for {'n_neighbors': 6, 'p': 3, 'weights': 'distance'}
# 0.653 (+/-0.022) for {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.658 (+/-0.024) for {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.668 (+/-0.022) for {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.666 (+/-0.018) for {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.666 (+/-0.015) for {'n_neighbors': 7, 'p': 3, 'weights': 'uniform'}
# 0.661 (+/-0.014) for {'n_neighbors': 7, 'p': 3, 'weights': 'distance'}
# 0.638 (+/-0.027) for {'n_neighbors': 8, 'p': 1, 'weights': 'uniform'}
# 0.661 (+/-0.024) for {'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
# 0.645 (+/-0.030) for {'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
# 0.655 (+/-0.028) for {'n_neighbors': 8, 'p': 2, 'weights': 'distance'}
# 0.647 (+/-0.019) for {'n_neighbors': 8, 'p': 3, 'weights': 'uniform'}
# 0.654 (+/-0.026) for {'n_neighbors': 8, 'p': 3, 'weights': 'distance'}
# 0.647 (+/-0.040) for {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.649 (+/-0.034) for {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.670 (+/-0.019) for {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.662 (+/-0.012) for {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.677 (+/-0.013) for {'n_neighbors': 9, 'p': 3, 'weights': 'uniform'}
# 0.670 (+/-0.011) for {'n_neighbors': 9, 'p': 3, 'weights': 'distance'}
# 0.634 (+/-0.041) for {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.654 (+/-0.024) for {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.660 (+/-0.019) for {'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.662 (+/-0.014) for {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.660 (+/-0.018) for {'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.656 (+/-0.024) for {'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.657 (+/-0.045) for {'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}
# 0.650 (+/-0.036) for {'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# 0.670 (+/-0.009) for {'n_neighbors': 11, 'p': 2, 'weights': 'uniform'}
# 0.661 (+/-0.006) for {'n_neighbors': 11, 'p': 2, 'weights': 'distance'}
# 0.663 (+/-0.012) for {'n_neighbors': 11, 'p': 3, 'weights': 'uniform'}
# 0.661 (+/-0.011) for {'n_neighbors': 11, 'p': 3, 'weights': 'distance'}
# 0.652 (+/-0.040) for {'n_neighbors': 12, 'p': 1, 'weights': 'uniform'}
# 0.667 (+/-0.024) for {'n_neighbors': 12, 'p': 1, 'weights': 'distance'}
# 0.658 (+/-0.018) for {'n_neighbors': 12, 'p': 2, 'weights': 'uniform'}
# 0.656 (+/-0.012) for {'n_neighbors': 12, 'p': 2, 'weights': 'distance'}
# 0.656 (+/-0.015) for {'n_neighbors': 12, 'p': 3, 'weights': 'uniform'}
# 0.653 (+/-0.015) for {'n_neighbors': 12, 'p': 3, 'weights': 'distance'}
# 0.662 (+/-0.031) for {'n_neighbors': 13, 'p': 1, 'weights': 'uniform'}
# 0.654 (+/-0.023) for {'n_neighbors': 13, 'p': 1, 'weights': 'distance'}
# 0.675 (+/-0.015) for {'n_neighbors': 13, 'p': 2, 'weights': 'uniform'}
# 0.668 (+/-0.008) for {'n_neighbors': 13, 'p': 2, 'weights': 'distance'}
# 0.673 (+/-0.018) for {'n_neighbors': 13, 'p': 3, 'weights': 'uniform'}
# 0.664 (+/-0.013) for {'n_neighbors': 13, 'p': 3, 'weights': 'distance'}
# 0.656 (+/-0.047) for {'n_neighbors': 14, 'p': 1, 'weights': 'uniform'}
# 0.669 (+/-0.026) for {'n_neighbors': 14, 'p': 1, 'weights': 'distance'}
# 0.652 (+/-0.018) for {'n_neighbors': 14, 'p': 2, 'weights': 'uniform'}
# 0.656 (+/-0.010) for {'n_neighbors': 14, 'p': 2, 'weights': 'distance'}
# 0.650 (+/-0.023) for {'n_neighbors': 14, 'p': 3, 'weights': 'uniform'}
# 0.653 (+/-0.020) for {'n_neighbors': 14, 'p': 3, 'weights': 'distance'}
# 0.687 (+/-0.042) for {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
# 0.671 (+/-0.034) for {'n_neighbors': 15, 'p': 1, 'weights': 'distance'}
# 0.673 (+/-0.029) for {'n_neighbors': 15, 'p': 2, 'weights': 'uniform'}
# 0.666 (+/-0.020) for {'n_neighbors': 15, 'p': 2, 'weights': 'distance'}
# 0.658 (+/-0.011) for {'n_neighbors': 15, 'p': 3, 'weights': 'uniform'}
# 0.661 (+/-0.009) for {'n_neighbors': 15, 'p': 3, 'weights': 'distance'}
# 0.668 (+/-0.036) for {'n_neighbors': 16, 'p': 1, 'weights': 'uniform'}
# 0.671 (+/-0.030) for {'n_neighbors': 16, 'p': 1, 'weights': 'distance'}
# 0.665 (+/-0.035) for {'n_neighbors': 16, 'p': 2, 'weights': 'uniform'}
# 0.659 (+/-0.020) for {'n_neighbors': 16, 'p': 2, 'weights': 'distance'}
# 0.653 (+/-0.027) for {'n_neighbors': 16, 'p': 3, 'weights': 'uniform'}
# 0.662 (+/-0.016) for {'n_neighbors': 16, 'p': 3, 'weights': 'distance'}
# 0.686 (+/-0.044) for {'n_neighbors': 17, 'p': 1, 'weights': 'uniform'}
# 0.674 (+/-0.031) for {'n_neighbors': 17, 'p': 1, 'weights': 'distance'}
# 0.662 (+/-0.036) for {'n_neighbors': 17, 'p': 2, 'weights': 'uniform'}
# 0.659 (+/-0.029) for {'n_neighbors': 17, 'p': 2, 'weights': 'distance'}
# 0.661 (+/-0.028) for {'n_neighbors': 17, 'p': 3, 'weights': 'uniform'}
# 0.660 (+/-0.020) for {'n_neighbors': 17, 'p': 3, 'weights': 'distance'}
# 0.671 (+/-0.046) for {'n_neighbors': 18, 'p': 1, 'weights': 'uniform'}
# 0.666 (+/-0.039) for {'n_neighbors': 18, 'p': 1, 'weights': 'distance'}
# 0.659 (+/-0.034) for {'n_neighbors': 18, 'p': 2, 'weights': 'uniform'}
# 0.659 (+/-0.030) for {'n_neighbors': 18, 'p': 2, 'weights': 'distance'}
# 0.654 (+/-0.042) for {'n_neighbors': 18, 'p': 3, 'weights': 'uniform'}
# 0.656 (+/-0.022) for {'n_neighbors': 18, 'p': 3, 'weights': 'distance'}
# 0.682 (+/-0.044) for {'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# 0.666 (+/-0.033) for {'n_neighbors': 19, 'p': 1, 'weights': 'distance'}
# 0.668 (+/-0.031) for {'n_neighbors': 19, 'p': 2, 'weights': 'uniform'}
# 0.663 (+/-0.020) for {'n_neighbors': 19, 'p': 2, 'weights': 'distance'}
# 0.657 (+/-0.039) for {'n_neighbors': 19, 'p': 3, 'weights': 'uniform'}
# 0.657 (+/-0.028) for {'n_neighbors': 19, 'p': 3, 'weights': 'distance'}
# 0.663 (+/-0.042) for {'n_neighbors': 20, 'p': 1, 'weights': 'uniform'}
# 0.667 (+/-0.040) for {'n_neighbors': 20, 'p': 1, 'weights': 'distance'}
# 0.650 (+/-0.038) for {'n_neighbors': 20, 'p': 2, 'weights': 'uniform'}
# 0.671 (+/-0.029) for {'n_neighbors': 20, 'p': 2, 'weights': 'distance'}
# 0.651 (+/-0.046) for {'n_neighbors': 20, 'p': 3, 'weights': 'uniform'}
# 0.657 (+/-0.031) for {'n_neighbors': 20, 'p': 3, 'weights': 'distance'}
# 0.680 (+/-0.050) for {'n_neighbors': 21, 'p': 1, 'weights': 'uniform'}
# 0.670 (+/-0.039) for {'n_neighbors': 21, 'p': 1, 'weights': 'distance'}
# 0.665 (+/-0.037) for {'n_neighbors': 21, 'p': 2, 'weights': 'uniform'}
# 0.661 (+/-0.035) for {'n_neighbors': 21, 'p': 2, 'weights': 'distance'}
# 0.661 (+/-0.042) for {'n_neighbors': 21, 'p': 3, 'weights': 'uniform'}
# 0.659 (+/-0.030) for {'n_neighbors': 21, 'p': 3, 'weights': 'distance'}
# 0.660 (+/-0.046) for {'n_neighbors': 22, 'p': 1, 'weights': 'uniform'}
# 0.677 (+/-0.035) for {'n_neighbors': 22, 'p': 1, 'weights': 'distance'}
# 0.659 (+/-0.036) for {'n_neighbors': 22, 'p': 2, 'weights': 'uniform'}
# 0.658 (+/-0.033) for {'n_neighbors': 22, 'p': 2, 'weights': 'distance'}
# 0.654 (+/-0.047) for {'n_neighbors': 22, 'p': 3, 'weights': 'uniform'}
# 0.661 (+/-0.033) for {'n_neighbors': 22, 'p': 3, 'weights': 'distance'}
# 0.672 (+/-0.043) for {'n_neighbors': 23, 'p': 1, 'weights': 'uniform'}
# 0.668 (+/-0.037) for {'n_neighbors': 23, 'p': 1, 'weights': 'distance'}
# 0.667 (+/-0.035) for {'n_neighbors': 23, 'p': 2, 'weights': 'uniform'}
# 0.654 (+/-0.029) for {'n_neighbors': 23, 'p': 2, 'weights': 'distance'}
# 0.668 (+/-0.044) for {'n_neighbors': 23, 'p': 3, 'weights': 'uniform'}
# 0.661 (+/-0.030) for {'n_neighbors': 23, 'p': 3, 'weights': 'distance'}
# 0.662 (+/-0.048) for {'n_neighbors': 24, 'p': 1, 'weights': 'uniform'}
# 0.667 (+/-0.032) for {'n_neighbors': 24, 'p': 1, 'weights': 'distance'}
# 0.666 (+/-0.041) for {'n_neighbors': 24, 'p': 2, 'weights': 'uniform'}
# 0.661 (+/-0.034) for {'n_neighbors': 24, 'p': 2, 'weights': 'distance'}
# 0.656 (+/-0.051) for {'n_neighbors': 24, 'p': 3, 'weights': 'uniform'}
# 0.658 (+/-0.035) for {'n_neighbors': 24, 'p': 3, 'weights': 'distance'}
# 0.672 (+/-0.042) for {'n_neighbors': 25, 'p': 1, 'weights': 'uniform'}
# 0.660 (+/-0.032) for {'n_neighbors': 25, 'p': 1, 'weights': 'distance'}
# 0.673 (+/-0.041) for {'n_neighbors': 25, 'p': 2, 'weights': 'uniform'}
# 0.662 (+/-0.043) for {'n_neighbors': 25, 'p': 2, 'weights': 'distance'}
# 0.672 (+/-0.044) for {'n_neighbors': 25, 'p': 3, 'weights': 'uniform'}
# 0.663 (+/-0.032) for {'n_neighbors': 25, 'p': 3, 'weights': 'distance'}
# 0.658 (+/-0.041) for {'n_neighbors': 26, 'p': 1, 'weights': 'uniform'}
# 0.665 (+/-0.040) for {'n_neighbors': 26, 'p': 1, 'weights': 'distance'}
# 0.661 (+/-0.041) for {'n_neighbors': 26, 'p': 2, 'weights': 'uniform'}
# 0.665 (+/-0.044) for {'n_neighbors': 26, 'p': 2, 'weights': 'distance'}
# 0.653 (+/-0.031) for {'n_neighbors': 26, 'p': 3, 'weights': 'uniform'}
# 0.664 (+/-0.036) for {'n_neighbors': 26, 'p': 3, 'weights': 'distance'}
# 0.677 (+/-0.044) for {'n_neighbors': 27, 'p': 1, 'weights': 'uniform'}
# 0.668 (+/-0.038) for {'n_neighbors': 27, 'p': 1, 'weights': 'distance'}
# 0.662 (+/-0.045) for {'n_neighbors': 27, 'p': 2, 'weights': 'uniform'}
# 0.658 (+/-0.042) for {'n_neighbors': 27, 'p': 2, 'weights': 'distance'}
# 0.663 (+/-0.027) for {'n_neighbors': 27, 'p': 3, 'weights': 'uniform'}
# 0.658 (+/-0.027) for {'n_neighbors': 27, 'p': 3, 'weights': 'distance'}
# 0.669 (+/-0.039) for {'n_neighbors': 28, 'p': 1, 'weights': 'uniform'}
# 0.667 (+/-0.040) for {'n_neighbors': 28, 'p': 1, 'weights': 'distance'}
# 0.654 (+/-0.038) for {'n_neighbors': 28, 'p': 2, 'weights': 'uniform'}
# 0.664 (+/-0.042) for {'n_neighbors': 28, 'p': 2, 'weights': 'distance'}
# 0.654 (+/-0.039) for {'n_neighbors': 28, 'p': 3, 'weights': 'uniform'}
# 0.656 (+/-0.029) for {'n_neighbors': 28, 'p': 3, 'weights': 'distance'}
# 0.672 (+/-0.042) for {'n_neighbors': 29, 'p': 1, 'weights': 'uniform'}
# 0.658 (+/-0.034) for {'n_neighbors': 29, 'p': 1, 'weights': 'distance'}
# 0.668 (+/-0.042) for {'n_neighbors': 29, 'p': 2, 'weights': 'uniform'}
# 0.660 (+/-0.042) for {'n_neighbors': 29, 'p': 2, 'weights': 'distance'}
# 0.666 (+/-0.034) for {'n_neighbors': 29, 'p': 3, 'weights': 'uniform'}
# 0.664 (+/-0.033) for {'n_neighbors': 29, 'p': 3, 'weights': 'distance'}
# 0.661 (+/-0.045) for {'n_neighbors': 30, 'p': 1, 'weights': 'uniform'}
# 0.665 (+/-0.032) for {'n_neighbors': 30, 'p': 1, 'weights': 'distance'}
# 0.669 (+/-0.054) for {'n_neighbors': 30, 'p': 2, 'weights': 'uniform'}
# 0.668 (+/-0.038) for {'n_neighbors': 30, 'p': 2, 'weights': 'distance'}
# 0.664 (+/-0.038) for {'n_neighbors': 30, 'p': 3, 'weights': 'uniform'}
# 0.666 (+/-0.031) for {'n_neighbors': 30, 'p': 3, 'weights': 'distance'}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.92      0.82       259
#          1.0       0.66      0.34      0.45       125
#
#     accuracy                           0.73       384
#    macro avg       0.70      0.63      0.64       384
# weighted avg       0.72      0.73      0.70       384
#
#
# Testing score:  0.7004606021975354
#
# Training Score:  0.712445576317261

# %% [markdown]
# # With SMOTE Oversampling

# %%
X_train = np.load('Data/X_train_smote.npy', allow_pickle= True)
y_train = np.load('Data/Y_train_smote.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 1202 1202 384 384

# %%
from sklearn.neighbors import KNeighborsClassifier #import the KNN classifier

tuned_parameters = [{
    'n_neighbors': [i for i in range(3,31,1)], 
    'p':  [k for k in range(1,4,1)],
    'weights' : ['uniform', 'distance']
    }]

clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'n_neighbors': 6, 'p': 1, 'weights': 'distance'}
#
#  Best Score 0.7923001197213463
#
#  Grid scores on development set:
# 0.758 (+/-0.045) for {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.791 (+/-0.045) for {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.718 (+/-0.026) for {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.742 (+/-0.028) for {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.709 (+/-0.030) for {'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.734 (+/-0.032) for {'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.743 (+/-0.053) for {'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
# 0.790 (+/-0.049) for {'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
# 0.715 (+/-0.047) for {'n_neighbors': 4, 'p': 2, 'weights': 'uniform'}
# 0.740 (+/-0.037) for {'n_neighbors': 4, 'p': 2, 'weights': 'distance'}
# 0.704 (+/-0.042) for {'n_neighbors': 4, 'p': 3, 'weights': 'uniform'}
# 0.731 (+/-0.037) for {'n_neighbors': 4, 'p': 3, 'weights': 'distance'}
# 0.747 (+/-0.043) for {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.789 (+/-0.043) for {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.699 (+/-0.040) for {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.731 (+/-0.042) for {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.688 (+/-0.036) for {'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.718 (+/-0.033) for {'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.723 (+/-0.063) for {'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}
# 0.792 (+/-0.042) for {'n_neighbors': 6, 'p': 1, 'weights': 'distance'}
# 0.696 (+/-0.056) for {'n_neighbors': 6, 'p': 2, 'weights': 'uniform'}
# 0.730 (+/-0.044) for {'n_neighbors': 6, 'p': 2, 'weights': 'distance'}
# 0.693 (+/-0.051) for {'n_neighbors': 6, 'p': 3, 'weights': 'uniform'}
# 0.727 (+/-0.041) for {'n_neighbors': 6, 'p': 3, 'weights': 'distance'}
# 0.713 (+/-0.054) for {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.775 (+/-0.044) for {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.691 (+/-0.046) for {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.729 (+/-0.042) for {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.675 (+/-0.048) for {'n_neighbors': 7, 'p': 3, 'weights': 'uniform'}
# 0.709 (+/-0.041) for {'n_neighbors': 7, 'p': 3, 'weights': 'distance'}
# 0.713 (+/-0.047) for {'n_neighbors': 8, 'p': 1, 'weights': 'uniform'}
# 0.779 (+/-0.043) for {'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
# 0.685 (+/-0.042) for {'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
# 0.732 (+/-0.046) for {'n_neighbors': 8, 'p': 2, 'weights': 'distance'}
# 0.680 (+/-0.030) for {'n_neighbors': 8, 'p': 3, 'weights': 'uniform'}
# 0.717 (+/-0.041) for {'n_neighbors': 8, 'p': 3, 'weights': 'distance'}
# 0.703 (+/-0.041) for {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.766 (+/-0.037) for {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.671 (+/-0.038) for {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.721 (+/-0.050) for {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.666 (+/-0.024) for {'n_neighbors': 9, 'p': 3, 'weights': 'uniform'}
# 0.707 (+/-0.030) for {'n_neighbors': 9, 'p': 3, 'weights': 'distance'}
# 0.707 (+/-0.040) for {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.775 (+/-0.044) for {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.671 (+/-0.032) for {'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.713 (+/-0.038) for {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.676 (+/-0.033) for {'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.714 (+/-0.028) for {'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.711 (+/-0.028) for {'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}
# 0.774 (+/-0.042) for {'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# 0.662 (+/-0.031) for {'n_neighbors': 11, 'p': 2, 'weights': 'uniform'}
# 0.714 (+/-0.038) for {'n_neighbors': 11, 'p': 2, 'weights': 'distance'}
# 0.648 (+/-0.030) for {'n_neighbors': 11, 'p': 3, 'weights': 'uniform'}
# 0.698 (+/-0.029) for {'n_neighbors': 11, 'p': 3, 'weights': 'distance'}
# 0.715 (+/-0.044) for {'n_neighbors': 12, 'p': 1, 'weights': 'uniform'}
# 0.787 (+/-0.032) for {'n_neighbors': 12, 'p': 1, 'weights': 'distance'}
# 0.680 (+/-0.029) for {'n_neighbors': 12, 'p': 2, 'weights': 'uniform'}
# 0.724 (+/-0.035) for {'n_neighbors': 12, 'p': 2, 'weights': 'distance'}
# 0.668 (+/-0.039) for {'n_neighbors': 12, 'p': 3, 'weights': 'uniform'}
# 0.703 (+/-0.033) for {'n_neighbors': 12, 'p': 3, 'weights': 'distance'}
# 0.705 (+/-0.034) for {'n_neighbors': 13, 'p': 1, 'weights': 'uniform'}
# 0.768 (+/-0.030) for {'n_neighbors': 13, 'p': 1, 'weights': 'distance'}
# 0.657 (+/-0.017) for {'n_neighbors': 13, 'p': 2, 'weights': 'uniform'}
# 0.701 (+/-0.026) for {'n_neighbors': 13, 'p': 2, 'weights': 'distance'}
# 0.651 (+/-0.030) for {'n_neighbors': 13, 'p': 3, 'weights': 'uniform'}
# 0.686 (+/-0.032) for {'n_neighbors': 13, 'p': 3, 'weights': 'distance'}
# 0.706 (+/-0.036) for {'n_neighbors': 14, 'p': 1, 'weights': 'uniform'}
# 0.771 (+/-0.024) for {'n_neighbors': 14, 'p': 1, 'weights': 'distance'}
# 0.677 (+/-0.032) for {'n_neighbors': 14, 'p': 2, 'weights': 'uniform'}
# 0.707 (+/-0.029) for {'n_neighbors': 14, 'p': 2, 'weights': 'distance'}
# 0.668 (+/-0.036) for {'n_neighbors': 14, 'p': 3, 'weights': 'uniform'}
# 0.694 (+/-0.033) for {'n_neighbors': 14, 'p': 3, 'weights': 'distance'}
# 0.703 (+/-0.027) for {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
# 0.766 (+/-0.027) for {'n_neighbors': 15, 'p': 1, 'weights': 'distance'}
# 0.658 (+/-0.012) for {'n_neighbors': 15, 'p': 2, 'weights': 'uniform'}
# 0.703 (+/-0.028) for {'n_neighbors': 15, 'p': 2, 'weights': 'distance'}
# 0.647 (+/-0.029) for {'n_neighbors': 15, 'p': 3, 'weights': 'uniform'}
# 0.687 (+/-0.027) for {'n_neighbors': 15, 'p': 3, 'weights': 'distance'}
# 0.714 (+/-0.037) for {'n_neighbors': 16, 'p': 1, 'weights': 'uniform'}
# 0.770 (+/-0.033) for {'n_neighbors': 16, 'p': 1, 'weights': 'distance'}
# 0.674 (+/-0.018) for {'n_neighbors': 16, 'p': 2, 'weights': 'uniform'}
# 0.709 (+/-0.024) for {'n_neighbors': 16, 'p': 2, 'weights': 'distance'}
# 0.666 (+/-0.031) for {'n_neighbors': 16, 'p': 3, 'weights': 'uniform'}
# 0.685 (+/-0.033) for {'n_neighbors': 16, 'p': 3, 'weights': 'distance'}
# 0.712 (+/-0.023) for {'n_neighbors': 17, 'p': 1, 'weights': 'uniform'}
# 0.768 (+/-0.036) for {'n_neighbors': 17, 'p': 1, 'weights': 'distance'}
# 0.661 (+/-0.016) for {'n_neighbors': 17, 'p': 2, 'weights': 'uniform'}
# 0.708 (+/-0.020) for {'n_neighbors': 17, 'p': 2, 'weights': 'distance'}
# 0.660 (+/-0.023) for {'n_neighbors': 17, 'p': 3, 'weights': 'uniform'}
# 0.695 (+/-0.023) for {'n_neighbors': 17, 'p': 3, 'weights': 'distance'}
# 0.706 (+/-0.031) for {'n_neighbors': 18, 'p': 1, 'weights': 'uniform'}
# 0.764 (+/-0.024) for {'n_neighbors': 18, 'p': 1, 'weights': 'distance'}
# 0.672 (+/-0.026) for {'n_neighbors': 18, 'p': 2, 'weights': 'uniform'}
# 0.712 (+/-0.017) for {'n_neighbors': 18, 'p': 2, 'weights': 'distance'}
# 0.670 (+/-0.025) for {'n_neighbors': 18, 'p': 3, 'weights': 'uniform'}
# 0.698 (+/-0.029) for {'n_neighbors': 18, 'p': 3, 'weights': 'distance'}
# 0.707 (+/-0.032) for {'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# 0.761 (+/-0.024) for {'n_neighbors': 19, 'p': 1, 'weights': 'distance'}
# 0.658 (+/-0.020) for {'n_neighbors': 19, 'p': 2, 'weights': 'uniform'}
# 0.699 (+/-0.014) for {'n_neighbors': 19, 'p': 2, 'weights': 'distance'}
# 0.649 (+/-0.021) for {'n_neighbors': 19, 'p': 3, 'weights': 'uniform'}
# 0.688 (+/-0.027) for {'n_neighbors': 19, 'p': 3, 'weights': 'distance'}
# 0.712 (+/-0.039) for {'n_neighbors': 20, 'p': 1, 'weights': 'uniform'}
# 0.763 (+/-0.019) for {'n_neighbors': 20, 'p': 1, 'weights': 'distance'}
# 0.661 (+/-0.024) for {'n_neighbors': 20, 'p': 2, 'weights': 'uniform'}
# 0.700 (+/-0.014) for {'n_neighbors': 20, 'p': 2, 'weights': 'distance'}
# 0.663 (+/-0.019) for {'n_neighbors': 20, 'p': 3, 'weights': 'uniform'}
# 0.692 (+/-0.021) for {'n_neighbors': 20, 'p': 3, 'weights': 'distance'}
# 0.705 (+/-0.030) for {'n_neighbors': 21, 'p': 1, 'weights': 'uniform'}
# 0.759 (+/-0.022) for {'n_neighbors': 21, 'p': 1, 'weights': 'distance'}
# 0.658 (+/-0.012) for {'n_neighbors': 21, 'p': 2, 'weights': 'uniform'}
# 0.697 (+/-0.020) for {'n_neighbors': 21, 'p': 2, 'weights': 'distance'}
# 0.646 (+/-0.013) for {'n_neighbors': 21, 'p': 3, 'weights': 'uniform'}
# 0.687 (+/-0.022) for {'n_neighbors': 21, 'p': 3, 'weights': 'distance'}
# 0.698 (+/-0.032) for {'n_neighbors': 22, 'p': 1, 'weights': 'uniform'}
# 0.759 (+/-0.028) for {'n_neighbors': 22, 'p': 1, 'weights': 'distance'}
# 0.658 (+/-0.016) for {'n_neighbors': 22, 'p': 2, 'weights': 'uniform'}
# 0.699 (+/-0.017) for {'n_neighbors': 22, 'p': 2, 'weights': 'distance'}
# 0.652 (+/-0.020) for {'n_neighbors': 22, 'p': 3, 'weights': 'uniform'}
# 0.695 (+/-0.021) for {'n_neighbors': 22, 'p': 3, 'weights': 'distance'}
# 0.689 (+/-0.034) for {'n_neighbors': 23, 'p': 1, 'weights': 'uniform'}
# 0.749 (+/-0.030) for {'n_neighbors': 23, 'p': 1, 'weights': 'distance'}
# 0.655 (+/-0.013) for {'n_neighbors': 23, 'p': 2, 'weights': 'uniform'}
# 0.696 (+/-0.013) for {'n_neighbors': 23, 'p': 2, 'weights': 'distance'}
# 0.644 (+/-0.006) for {'n_neighbors': 23, 'p': 3, 'weights': 'uniform'}
# 0.690 (+/-0.021) for {'n_neighbors': 23, 'p': 3, 'weights': 'distance'}
# 0.696 (+/-0.035) for {'n_neighbors': 24, 'p': 1, 'weights': 'uniform'}
# 0.752 (+/-0.028) for {'n_neighbors': 24, 'p': 1, 'weights': 'distance'}
# 0.654 (+/-0.015) for {'n_neighbors': 24, 'p': 2, 'weights': 'uniform'}
# 0.696 (+/-0.016) for {'n_neighbors': 24, 'p': 2, 'weights': 'distance'}
# 0.647 (+/-0.008) for {'n_neighbors': 24, 'p': 3, 'weights': 'uniform'}
# 0.692 (+/-0.025) for {'n_neighbors': 24, 'p': 3, 'weights': 'distance'}
# 0.685 (+/-0.029) for {'n_neighbors': 25, 'p': 1, 'weights': 'uniform'}
# 0.744 (+/-0.031) for {'n_neighbors': 25, 'p': 1, 'weights': 'distance'}
# 0.646 (+/-0.020) for {'n_neighbors': 25, 'p': 2, 'weights': 'uniform'}
# 0.690 (+/-0.014) for {'n_neighbors': 25, 'p': 2, 'weights': 'distance'}
# 0.643 (+/-0.007) for {'n_neighbors': 25, 'p': 3, 'weights': 'uniform'}
# 0.687 (+/-0.022) for {'n_neighbors': 25, 'p': 3, 'weights': 'distance'}
# 0.683 (+/-0.025) for {'n_neighbors': 26, 'p': 1, 'weights': 'uniform'}
# 0.752 (+/-0.024) for {'n_neighbors': 26, 'p': 1, 'weights': 'distance'}
# 0.652 (+/-0.017) for {'n_neighbors': 26, 'p': 2, 'weights': 'uniform'}
# 0.694 (+/-0.015) for {'n_neighbors': 26, 'p': 2, 'weights': 'distance'}
# 0.654 (+/-0.006) for {'n_neighbors': 26, 'p': 3, 'weights': 'uniform'}
# 0.688 (+/-0.017) for {'n_neighbors': 26, 'p': 3, 'weights': 'distance'}
# 0.681 (+/-0.024) for {'n_neighbors': 27, 'p': 1, 'weights': 'uniform'}
# 0.745 (+/-0.026) for {'n_neighbors': 27, 'p': 1, 'weights': 'distance'}
# 0.645 (+/-0.017) for {'n_neighbors': 27, 'p': 2, 'weights': 'uniform'}
# 0.692 (+/-0.015) for {'n_neighbors': 27, 'p': 2, 'weights': 'distance'}
# 0.639 (+/-0.012) for {'n_neighbors': 27, 'p': 3, 'weights': 'uniform'}
# 0.684 (+/-0.018) for {'n_neighbors': 27, 'p': 3, 'weights': 'distance'}
# 0.683 (+/-0.033) for {'n_neighbors': 28, 'p': 1, 'weights': 'uniform'}
# 0.748 (+/-0.030) for {'n_neighbors': 28, 'p': 1, 'weights': 'distance'}
# 0.644 (+/-0.019) for {'n_neighbors': 28, 'p': 2, 'weights': 'uniform'}
# 0.689 (+/-0.016) for {'n_neighbors': 28, 'p': 2, 'weights': 'distance'}
# 0.642 (+/-0.014) for {'n_neighbors': 28, 'p': 3, 'weights': 'uniform'}
# 0.681 (+/-0.020) for {'n_neighbors': 28, 'p': 3, 'weights': 'distance'}
# 0.680 (+/-0.026) for {'n_neighbors': 29, 'p': 1, 'weights': 'uniform'}
# 0.744 (+/-0.028) for {'n_neighbors': 29, 'p': 1, 'weights': 'distance'}
# 0.643 (+/-0.018) for {'n_neighbors': 29, 'p': 2, 'weights': 'uniform'}
# 0.688 (+/-0.014) for {'n_neighbors': 29, 'p': 2, 'weights': 'distance'}
# 0.640 (+/-0.010) for {'n_neighbors': 29, 'p': 3, 'weights': 'uniform'}
# 0.681 (+/-0.019) for {'n_neighbors': 29, 'p': 3, 'weights': 'distance'}
# 0.676 (+/-0.027) for {'n_neighbors': 30, 'p': 1, 'weights': 'uniform'}
# 0.746 (+/-0.023) for {'n_neighbors': 30, 'p': 1, 'weights': 'distance'}
# 0.655 (+/-0.024) for {'n_neighbors': 30, 'p': 2, 'weights': 'uniform'}
# 0.687 (+/-0.014) for {'n_neighbors': 30, 'p': 2, 'weights': 'distance'}
# 0.648 (+/-0.012) for {'n_neighbors': 30, 'p': 3, 'weights': 'uniform'}
# 0.678 (+/-0.013) for {'n_neighbors': 30, 'p': 3, 'weights': 'distance'}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.76      0.76       259
#          1.0       0.51      0.53      0.52       125
#
#     accuracy                           0.68       384
#    macro avg       0.64      0.64      0.64       384
# weighted avg       0.68      0.68      0.68       384
#
#
# Testing score:  0.6835570878907645
#
# Training Score:  1.0

# %% [markdown]
# # With Borderline-SMOTE Oversampling

# %%
X_train = np.load('Data/X_train_borderline_smote.npy', allow_pickle= True)
y_train = np.load('Data/Y_train_borderline_smote.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 1202 1202 384 384

# %%
from sklearn.neighbors import KNeighborsClassifier #import the KNN classifier

tuned_parameters = [{
    'n_neighbors': [i for i in range(3,31,1)], 
    'p':  [k for k in range(1,4,1)],
    'weights' : ['uniform', 'distance']
    }]

clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
#
#  Best Score 0.7862317034572374
#
#  Grid scores on development set:
# 0.764 (+/-0.036) for {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.786 (+/-0.042) for {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.727 (+/-0.026) for {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.744 (+/-0.027) for {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.711 (+/-0.025) for {'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.726 (+/-0.019) for {'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.750 (+/-0.052) for {'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
# 0.786 (+/-0.034) for {'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
# 0.726 (+/-0.039) for {'n_neighbors': 4, 'p': 2, 'weights': 'uniform'}
# 0.752 (+/-0.032) for {'n_neighbors': 4, 'p': 2, 'weights': 'distance'}
# 0.712 (+/-0.026) for {'n_neighbors': 4, 'p': 3, 'weights': 'uniform'}
# 0.734 (+/-0.029) for {'n_neighbors': 4, 'p': 3, 'weights': 'distance'}
# 0.753 (+/-0.033) for {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.785 (+/-0.037) for {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.708 (+/-0.033) for {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.729 (+/-0.033) for {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.696 (+/-0.020) for {'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.715 (+/-0.022) for {'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.743 (+/-0.041) for {'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}
# 0.783 (+/-0.039) for {'n_neighbors': 6, 'p': 1, 'weights': 'distance'}
# 0.706 (+/-0.030) for {'n_neighbors': 6, 'p': 2, 'weights': 'uniform'}
# 0.734 (+/-0.033) for {'n_neighbors': 6, 'p': 2, 'weights': 'distance'}
# 0.696 (+/-0.021) for {'n_neighbors': 6, 'p': 3, 'weights': 'uniform'}
# 0.720 (+/-0.025) for {'n_neighbors': 6, 'p': 3, 'weights': 'distance'}
# 0.738 (+/-0.029) for {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.769 (+/-0.031) for {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.691 (+/-0.018) for {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.717 (+/-0.019) for {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.673 (+/-0.018) for {'n_neighbors': 7, 'p': 3, 'weights': 'uniform'}
# 0.702 (+/-0.021) for {'n_neighbors': 7, 'p': 3, 'weights': 'distance'}
# 0.732 (+/-0.034) for {'n_neighbors': 8, 'p': 1, 'weights': 'uniform'}
# 0.776 (+/-0.027) for {'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
# 0.697 (+/-0.019) for {'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
# 0.723 (+/-0.019) for {'n_neighbors': 8, 'p': 2, 'weights': 'distance'}
# 0.687 (+/-0.020) for {'n_neighbors': 8, 'p': 3, 'weights': 'uniform'}
# 0.706 (+/-0.019) for {'n_neighbors': 8, 'p': 3, 'weights': 'distance'}
# 0.722 (+/-0.026) for {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.768 (+/-0.028) for {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.680 (+/-0.015) for {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.711 (+/-0.021) for {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.674 (+/-0.012) for {'n_neighbors': 9, 'p': 3, 'weights': 'uniform'}
# 0.704 (+/-0.017) for {'n_neighbors': 9, 'p': 3, 'weights': 'distance'}
# 0.708 (+/-0.028) for {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.769 (+/-0.023) for {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.687 (+/-0.020) for {'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.717 (+/-0.016) for {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.679 (+/-0.020) for {'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.710 (+/-0.020) for {'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.712 (+/-0.016) for {'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}
# 0.762 (+/-0.025) for {'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# 0.679 (+/-0.024) for {'n_neighbors': 11, 'p': 2, 'weights': 'uniform'}
# 0.718 (+/-0.023) for {'n_neighbors': 11, 'p': 2, 'weights': 'distance'}
# 0.652 (+/-0.011) for {'n_neighbors': 11, 'p': 3, 'weights': 'uniform'}
# 0.694 (+/-0.016) for {'n_neighbors': 11, 'p': 3, 'weights': 'distance'}
# 0.697 (+/-0.031) for {'n_neighbors': 12, 'p': 1, 'weights': 'uniform'}
# 0.771 (+/-0.027) for {'n_neighbors': 12, 'p': 1, 'weights': 'distance'}
# 0.676 (+/-0.016) for {'n_neighbors': 12, 'p': 2, 'weights': 'uniform'}
# 0.711 (+/-0.019) for {'n_neighbors': 12, 'p': 2, 'weights': 'distance'}
# 0.662 (+/-0.012) for {'n_neighbors': 12, 'p': 3, 'weights': 'uniform'}
# 0.700 (+/-0.013) for {'n_neighbors': 12, 'p': 3, 'weights': 'distance'}
# 0.703 (+/-0.020) for {'n_neighbors': 13, 'p': 1, 'weights': 'uniform'}
# 0.760 (+/-0.023) for {'n_neighbors': 13, 'p': 1, 'weights': 'distance'}
# 0.659 (+/-0.016) for {'n_neighbors': 13, 'p': 2, 'weights': 'uniform'}
# 0.701 (+/-0.022) for {'n_neighbors': 13, 'p': 2, 'weights': 'distance'}
# 0.653 (+/-0.015) for {'n_neighbors': 13, 'p': 3, 'weights': 'uniform'}
# 0.695 (+/-0.011) for {'n_neighbors': 13, 'p': 3, 'weights': 'distance'}
# 0.701 (+/-0.030) for {'n_neighbors': 14, 'p': 1, 'weights': 'uniform'}
# 0.759 (+/-0.023) for {'n_neighbors': 14, 'p': 1, 'weights': 'distance'}
# 0.664 (+/-0.010) for {'n_neighbors': 14, 'p': 2, 'weights': 'uniform'}
# 0.704 (+/-0.018) for {'n_neighbors': 14, 'p': 2, 'weights': 'distance'}
# 0.659 (+/-0.018) for {'n_neighbors': 14, 'p': 3, 'weights': 'uniform'}
# 0.697 (+/-0.018) for {'n_neighbors': 14, 'p': 3, 'weights': 'distance'}
# 0.694 (+/-0.015) for {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
# 0.757 (+/-0.020) for {'n_neighbors': 15, 'p': 1, 'weights': 'distance'}
# 0.651 (+/-0.019) for {'n_neighbors': 15, 'p': 2, 'weights': 'uniform'}
# 0.698 (+/-0.018) for {'n_neighbors': 15, 'p': 2, 'weights': 'distance'}
# 0.647 (+/-0.018) for {'n_neighbors': 15, 'p': 3, 'weights': 'uniform'}
# 0.692 (+/-0.012) for {'n_neighbors': 15, 'p': 3, 'weights': 'distance'}
# 0.693 (+/-0.020) for {'n_neighbors': 16, 'p': 1, 'weights': 'uniform'}
# 0.755 (+/-0.015) for {'n_neighbors': 16, 'p': 1, 'weights': 'distance'}
# 0.654 (+/-0.026) for {'n_neighbors': 16, 'p': 2, 'weights': 'uniform'}
# 0.699 (+/-0.022) for {'n_neighbors': 16, 'p': 2, 'weights': 'distance'}
# 0.652 (+/-0.027) for {'n_neighbors': 16, 'p': 3, 'weights': 'uniform'}
# 0.688 (+/-0.017) for {'n_neighbors': 16, 'p': 3, 'weights': 'distance'}
# 0.691 (+/-0.018) for {'n_neighbors': 17, 'p': 1, 'weights': 'uniform'}
# 0.750 (+/-0.015) for {'n_neighbors': 17, 'p': 1, 'weights': 'distance'}
# 0.644 (+/-0.032) for {'n_neighbors': 17, 'p': 2, 'weights': 'uniform'}
# 0.696 (+/-0.025) for {'n_neighbors': 17, 'p': 2, 'weights': 'distance'}
# 0.643 (+/-0.013) for {'n_neighbors': 17, 'p': 3, 'weights': 'uniform'}
# 0.686 (+/-0.010) for {'n_neighbors': 17, 'p': 3, 'weights': 'distance'}
# 0.694 (+/-0.025) for {'n_neighbors': 18, 'p': 1, 'weights': 'uniform'}
# 0.758 (+/-0.013) for {'n_neighbors': 18, 'p': 1, 'weights': 'distance'}
# 0.649 (+/-0.020) for {'n_neighbors': 18, 'p': 2, 'weights': 'uniform'}
# 0.692 (+/-0.021) for {'n_neighbors': 18, 'p': 2, 'weights': 'distance'}
# 0.649 (+/-0.015) for {'n_neighbors': 18, 'p': 3, 'weights': 'uniform'}
# 0.691 (+/-0.013) for {'n_neighbors': 18, 'p': 3, 'weights': 'distance'}
# 0.690 (+/-0.029) for {'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# 0.752 (+/-0.016) for {'n_neighbors': 19, 'p': 1, 'weights': 'distance'}
# 0.643 (+/-0.020) for {'n_neighbors': 19, 'p': 2, 'weights': 'uniform'}
# 0.690 (+/-0.016) for {'n_neighbors': 19, 'p': 2, 'weights': 'distance'}
# 0.642 (+/-0.014) for {'n_neighbors': 19, 'p': 3, 'weights': 'uniform'}
# 0.682 (+/-0.013) for {'n_neighbors': 19, 'p': 3, 'weights': 'distance'}
# 0.687 (+/-0.026) for {'n_neighbors': 20, 'p': 1, 'weights': 'uniform'}
# 0.747 (+/-0.016) for {'n_neighbors': 20, 'p': 1, 'weights': 'distance'}
# 0.640 (+/-0.017) for {'n_neighbors': 20, 'p': 2, 'weights': 'uniform'}
# 0.685 (+/-0.010) for {'n_neighbors': 20, 'p': 2, 'weights': 'distance'}
# 0.642 (+/-0.017) for {'n_neighbors': 20, 'p': 3, 'weights': 'uniform'}
# 0.678 (+/-0.014) for {'n_neighbors': 20, 'p': 3, 'weights': 'distance'}
# 0.687 (+/-0.006) for {'n_neighbors': 21, 'p': 1, 'weights': 'uniform'}
# 0.748 (+/-0.017) for {'n_neighbors': 21, 'p': 1, 'weights': 'distance'}
# 0.644 (+/-0.020) for {'n_neighbors': 21, 'p': 2, 'weights': 'uniform'}
# 0.683 (+/-0.016) for {'n_neighbors': 21, 'p': 2, 'weights': 'distance'}
# 0.630 (+/-0.024) for {'n_neighbors': 21, 'p': 3, 'weights': 'uniform'}
# 0.667 (+/-0.014) for {'n_neighbors': 21, 'p': 3, 'weights': 'distance'}
# 0.686 (+/-0.017) for {'n_neighbors': 22, 'p': 1, 'weights': 'uniform'}
# 0.757 (+/-0.016) for {'n_neighbors': 22, 'p': 1, 'weights': 'distance'}
# 0.640 (+/-0.010) for {'n_neighbors': 22, 'p': 2, 'weights': 'uniform'}
# 0.682 (+/-0.015) for {'n_neighbors': 22, 'p': 2, 'weights': 'distance'}
# 0.624 (+/-0.022) for {'n_neighbors': 22, 'p': 3, 'weights': 'uniform'}
# 0.667 (+/-0.022) for {'n_neighbors': 22, 'p': 3, 'weights': 'distance'}
# 0.682 (+/-0.015) for {'n_neighbors': 23, 'p': 1, 'weights': 'uniform'}
# 0.757 (+/-0.012) for {'n_neighbors': 23, 'p': 1, 'weights': 'distance'}
# 0.637 (+/-0.016) for {'n_neighbors': 23, 'p': 2, 'weights': 'uniform'}
# 0.682 (+/-0.012) for {'n_neighbors': 23, 'p': 2, 'weights': 'distance'}
# 0.628 (+/-0.021) for {'n_neighbors': 23, 'p': 3, 'weights': 'uniform'}
# 0.663 (+/-0.024) for {'n_neighbors': 23, 'p': 3, 'weights': 'distance'}
# 0.683 (+/-0.016) for {'n_neighbors': 24, 'p': 1, 'weights': 'uniform'}
# 0.759 (+/-0.021) for {'n_neighbors': 24, 'p': 1, 'weights': 'distance'}
# 0.634 (+/-0.015) for {'n_neighbors': 24, 'p': 2, 'weights': 'uniform'}
# 0.680 (+/-0.016) for {'n_neighbors': 24, 'p': 2, 'weights': 'distance'}
# 0.621 (+/-0.019) for {'n_neighbors': 24, 'p': 3, 'weights': 'uniform'}
# 0.664 (+/-0.021) for {'n_neighbors': 24, 'p': 3, 'weights': 'distance'}
# 0.679 (+/-0.016) for {'n_neighbors': 25, 'p': 1, 'weights': 'uniform'}
# 0.755 (+/-0.025) for {'n_neighbors': 25, 'p': 1, 'weights': 'distance'}
# 0.634 (+/-0.017) for {'n_neighbors': 25, 'p': 2, 'weights': 'uniform'}
# 0.684 (+/-0.020) for {'n_neighbors': 25, 'p': 2, 'weights': 'distance'}
# 0.626 (+/-0.016) for {'n_neighbors': 25, 'p': 3, 'weights': 'uniform'}
# 0.665 (+/-0.026) for {'n_neighbors': 25, 'p': 3, 'weights': 'distance'}
# 0.675 (+/-0.018) for {'n_neighbors': 26, 'p': 1, 'weights': 'uniform'}
# 0.753 (+/-0.025) for {'n_neighbors': 26, 'p': 1, 'weights': 'distance'}
# 0.635 (+/-0.021) for {'n_neighbors': 26, 'p': 2, 'weights': 'uniform'}
# 0.681 (+/-0.019) for {'n_neighbors': 26, 'p': 2, 'weights': 'distance'}
# 0.622 (+/-0.022) for {'n_neighbors': 26, 'p': 3, 'weights': 'uniform'}
# 0.666 (+/-0.024) for {'n_neighbors': 26, 'p': 3, 'weights': 'distance'}
# 0.677 (+/-0.011) for {'n_neighbors': 27, 'p': 1, 'weights': 'uniform'}
# 0.750 (+/-0.023) for {'n_neighbors': 27, 'p': 1, 'weights': 'distance'}
# 0.634 (+/-0.030) for {'n_neighbors': 27, 'p': 2, 'weights': 'uniform'}
# 0.680 (+/-0.021) for {'n_neighbors': 27, 'p': 2, 'weights': 'distance'}
# 0.628 (+/-0.025) for {'n_neighbors': 27, 'p': 3, 'weights': 'uniform'}
# 0.670 (+/-0.029) for {'n_neighbors': 27, 'p': 3, 'weights': 'distance'}
# 0.675 (+/-0.016) for {'n_neighbors': 28, 'p': 1, 'weights': 'uniform'}
# 0.744 (+/-0.021) for {'n_neighbors': 28, 'p': 1, 'weights': 'distance'}
# 0.631 (+/-0.023) for {'n_neighbors': 28, 'p': 2, 'weights': 'uniform'}
# 0.681 (+/-0.017) for {'n_neighbors': 28, 'p': 2, 'weights': 'distance'}
# 0.623 (+/-0.022) for {'n_neighbors': 28, 'p': 3, 'weights': 'uniform'}
# 0.663 (+/-0.028) for {'n_neighbors': 28, 'p': 3, 'weights': 'distance'}
# 0.676 (+/-0.017) for {'n_neighbors': 29, 'p': 1, 'weights': 'uniform'}
# 0.742 (+/-0.014) for {'n_neighbors': 29, 'p': 1, 'weights': 'distance'}
# 0.631 (+/-0.025) for {'n_neighbors': 29, 'p': 2, 'weights': 'uniform'}
# 0.675 (+/-0.020) for {'n_neighbors': 29, 'p': 2, 'weights': 'distance'}
# 0.622 (+/-0.026) for {'n_neighbors': 29, 'p': 3, 'weights': 'uniform'}
# 0.668 (+/-0.024) for {'n_neighbors': 29, 'p': 3, 'weights': 'distance'}
# 0.670 (+/-0.019) for {'n_neighbors': 30, 'p': 1, 'weights': 'uniform'}
# 0.744 (+/-0.022) for {'n_neighbors': 30, 'p': 1, 'weights': 'distance'}
# 0.629 (+/-0.020) for {'n_neighbors': 30, 'p': 2, 'weights': 'uniform'}
# 0.677 (+/-0.021) for {'n_neighbors': 30, 'p': 2, 'weights': 'distance'}
# 0.621 (+/-0.012) for {'n_neighbors': 30, 'p': 3, 'weights': 'uniform'}
# 0.670 (+/-0.026) for {'n_neighbors': 30, 'p': 3, 'weights': 'distance'}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.78      0.77       259
#          1.0       0.53      0.52      0.52       125
#
#     accuracy                           0.69       384
#    macro avg       0.65      0.65      0.65       384
# weighted avg       0.69      0.69      0.69       384
#
#
# Testing score:  0.6920601995450785
#
# Training Score:  1.0

# %% [markdown]
# # With ADASYN Oversampling

# %%
X_train = np.load('Data/X_train_adasyn.npy', allow_pickle= True)
y_train = np.load('Data/Y_train_adasyn.npy', allow_pickle= True)

#Remains same regardless of oversampling
X_test = np.load('Data/X_test.npy', allow_pickle= True)
y_test = np.load('Data/Y_test.npy', allow_pickle= True)


print(len(X_train),len(y_train),len(X_test),len(y_test))
# Out:
# 1168 1168 384 384

# %%
from sklearn.neighbors import KNeighborsClassifier #import the KNN classifier

tuned_parameters = [{
    'n_neighbors': [i for i in range(2,31,1)], 
    'p':  [k for k in range(1,4,1)],
    'weights' : ['uniform', 'distance']
    }]

clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, scoring='f1_weighted')
clf.fit(X_train, y_train)

#Evaluation

print("Best parameters set found on development set:\n", clf.best_params_)
print("\n Best Score", clf.best_score_) 

print("\n Grid scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std, params))

print("Detailed classification report:")
print("The scores are computed on the full evaluation set. \n")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#Lets print confision matrix
labels =['Continued','Discontinued']

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test,display_labels=labels,cmap=plt.cm.Blues)

print ('\nTesting score: ',clf.score (X_test, y_test)) # print the testing score(accuracy)
print ('\nTraining Score: ',clf.score (X_train, y_train)) # print the trainig score(accuracy)
# Out:
# Best parameters set found on development set:
#  {'n_neighbors': 2, 'p': 1, 'weights': 'distance'}
#
#  Best Score 0.828865763893458
#
#  Grid scores on development set:
# 0.744 (+/-0.037) for {'n_neighbors': 2, 'p': 1, 'weights': 'uniform'}
# 0.829 (+/-0.035) for {'n_neighbors': 2, 'p': 1, 'weights': 'distance'}
# 0.736 (+/-0.025) for {'n_neighbors': 2, 'p': 2, 'weights': 'uniform'}
# 0.799 (+/-0.016) for {'n_neighbors': 2, 'p': 2, 'weights': 'distance'}
# 0.712 (+/-0.031) for {'n_neighbors': 2, 'p': 3, 'weights': 'uniform'}
# 0.773 (+/-0.019) for {'n_neighbors': 2, 'p': 3, 'weights': 'distance'}
# 0.752 (+/-0.022) for {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.803 (+/-0.026) for {'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.696 (+/-0.017) for {'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.737 (+/-0.022) for {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.687 (+/-0.014) for {'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.724 (+/-0.017) for {'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.706 (+/-0.033) for {'n_neighbors': 4, 'p': 1, 'weights': 'uniform'}
# 0.806 (+/-0.027) for {'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
# 0.675 (+/-0.014) for {'n_neighbors': 4, 'p': 2, 'weights': 'uniform'}
# 0.755 (+/-0.015) for {'n_neighbors': 4, 'p': 2, 'weights': 'distance'}
# 0.668 (+/-0.020) for {'n_neighbors': 4, 'p': 3, 'weights': 'uniform'}
# 0.731 (+/-0.015) for {'n_neighbors': 4, 'p': 3, 'weights': 'distance'}
# 0.725 (+/-0.021) for {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.791 (+/-0.016) for {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.688 (+/-0.022) for {'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.741 (+/-0.023) for {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.671 (+/-0.034) for {'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.720 (+/-0.032) for {'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.694 (+/-0.028) for {'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}
# 0.791 (+/-0.026) for {'n_neighbors': 6, 'p': 1, 'weights': 'distance'}
# 0.658 (+/-0.018) for {'n_neighbors': 6, 'p': 2, 'weights': 'uniform'}
# 0.739 (+/-0.023) for {'n_neighbors': 6, 'p': 2, 'weights': 'distance'}
# 0.651 (+/-0.015) for {'n_neighbors': 6, 'p': 3, 'weights': 'uniform'}
# 0.726 (+/-0.028) for {'n_neighbors': 6, 'p': 3, 'weights': 'distance'}
# 0.709 (+/-0.022) for {'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.783 (+/-0.018) for {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.666 (+/-0.022) for {'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.722 (+/-0.029) for {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.655 (+/-0.021) for {'n_neighbors': 7, 'p': 3, 'weights': 'uniform'}
# 0.709 (+/-0.029) for {'n_neighbors': 7, 'p': 3, 'weights': 'distance'}
# 0.688 (+/-0.021) for {'n_neighbors': 8, 'p': 1, 'weights': 'uniform'}
# 0.789 (+/-0.022) for {'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
# 0.648 (+/-0.013) for {'n_neighbors': 8, 'p': 2, 'weights': 'uniform'}
# 0.729 (+/-0.023) for {'n_neighbors': 8, 'p': 2, 'weights': 'distance'}
# 0.641 (+/-0.019) for {'n_neighbors': 8, 'p': 3, 'weights': 'uniform'}
# 0.713 (+/-0.019) for {'n_neighbors': 8, 'p': 3, 'weights': 'distance'}
# 0.677 (+/-0.014) for {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.767 (+/-0.023) for {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.649 (+/-0.019) for {'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.717 (+/-0.023) for {'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.630 (+/-0.017) for {'n_neighbors': 9, 'p': 3, 'weights': 'uniform'}
# 0.696 (+/-0.022) for {'n_neighbors': 9, 'p': 3, 'weights': 'distance'}
# 0.663 (+/-0.008) for {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.775 (+/-0.030) for {'n_neighbors': 10, 'p': 1, 'weights': 'distance'}
# 0.652 (+/-0.024) for {'n_neighbors': 10, 'p': 2, 'weights': 'uniform'}
# 0.725 (+/-0.018) for {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}
# 0.649 (+/-0.032) for {'n_neighbors': 10, 'p': 3, 'weights': 'uniform'}
# 0.714 (+/-0.012) for {'n_neighbors': 10, 'p': 3, 'weights': 'distance'}
# 0.689 (+/-0.013) for {'n_neighbors': 11, 'p': 1, 'weights': 'uniform'}
# 0.774 (+/-0.025) for {'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# 0.638 (+/-0.029) for {'n_neighbors': 11, 'p': 2, 'weights': 'uniform'}
# 0.712 (+/-0.019) for {'n_neighbors': 11, 'p': 2, 'weights': 'distance'}
# 0.632 (+/-0.020) for {'n_neighbors': 11, 'p': 3, 'weights': 'uniform'}
# 0.700 (+/-0.015) for {'n_neighbors': 11, 'p': 3, 'weights': 'distance'}
# 0.671 (+/-0.019) for {'n_neighbors': 12, 'p': 1, 'weights': 'uniform'}
# 0.776 (+/-0.030) for {'n_neighbors': 12, 'p': 1, 'weights': 'distance'}
# 0.648 (+/-0.040) for {'n_neighbors': 12, 'p': 2, 'weights': 'uniform'}
# 0.714 (+/-0.033) for {'n_neighbors': 12, 'p': 2, 'weights': 'distance'}
# 0.627 (+/-0.029) for {'n_neighbors': 12, 'p': 3, 'weights': 'uniform'}
# 0.698 (+/-0.022) for {'n_neighbors': 12, 'p': 3, 'weights': 'distance'}
# 0.686 (+/-0.031) for {'n_neighbors': 13, 'p': 1, 'weights': 'uniform'}
# 0.773 (+/-0.026) for {'n_neighbors': 13, 'p': 1, 'weights': 'distance'}
# 0.633 (+/-0.026) for {'n_neighbors': 13, 'p': 2, 'weights': 'uniform'}
# 0.712 (+/-0.021) for {'n_neighbors': 13, 'p': 2, 'weights': 'distance'}
# 0.632 (+/-0.022) for {'n_neighbors': 13, 'p': 3, 'weights': 'uniform'}
# 0.702 (+/-0.018) for {'n_neighbors': 13, 'p': 3, 'weights': 'distance'}
# 0.672 (+/-0.025) for {'n_neighbors': 14, 'p': 1, 'weights': 'uniform'}
# 0.772 (+/-0.017) for {'n_neighbors': 14, 'p': 1, 'weights': 'distance'}
# 0.643 (+/-0.020) for {'n_neighbors': 14, 'p': 2, 'weights': 'uniform'}
# 0.714 (+/-0.017) for {'n_neighbors': 14, 'p': 2, 'weights': 'distance'}
# 0.637 (+/-0.015) for {'n_neighbors': 14, 'p': 3, 'weights': 'uniform'}
# 0.702 (+/-0.021) for {'n_neighbors': 14, 'p': 3, 'weights': 'distance'}
# 0.675 (+/-0.016) for {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}
# 0.760 (+/-0.022) for {'n_neighbors': 15, 'p': 1, 'weights': 'distance'}
# 0.643 (+/-0.024) for {'n_neighbors': 15, 'p': 2, 'weights': 'uniform'}
# 0.711 (+/-0.019) for {'n_neighbors': 15, 'p': 2, 'weights': 'distance'}
# 0.637 (+/-0.016) for {'n_neighbors': 15, 'p': 3, 'weights': 'uniform'}
# 0.695 (+/-0.028) for {'n_neighbors': 15, 'p': 3, 'weights': 'distance'}
# 0.668 (+/-0.024) for {'n_neighbors': 16, 'p': 1, 'weights': 'uniform'}
# 0.770 (+/-0.024) for {'n_neighbors': 16, 'p': 1, 'weights': 'distance'}
# 0.644 (+/-0.022) for {'n_neighbors': 16, 'p': 2, 'weights': 'uniform'}
# 0.706 (+/-0.023) for {'n_neighbors': 16, 'p': 2, 'weights': 'distance'}
# 0.646 (+/-0.015) for {'n_neighbors': 16, 'p': 3, 'weights': 'uniform'}
# 0.699 (+/-0.016) for {'n_neighbors': 16, 'p': 3, 'weights': 'distance'}
# 0.674 (+/-0.026) for {'n_neighbors': 17, 'p': 1, 'weights': 'uniform'}
# 0.764 (+/-0.026) for {'n_neighbors': 17, 'p': 1, 'weights': 'distance'}
# 0.650 (+/-0.023) for {'n_neighbors': 17, 'p': 2, 'weights': 'uniform'}
# 0.718 (+/-0.018) for {'n_neighbors': 17, 'p': 2, 'weights': 'distance'}
# 0.634 (+/-0.010) for {'n_neighbors': 17, 'p': 3, 'weights': 'uniform'}
# 0.693 (+/-0.017) for {'n_neighbors': 17, 'p': 3, 'weights': 'distance'}
# 0.660 (+/-0.028) for {'n_neighbors': 18, 'p': 1, 'weights': 'uniform'}
# 0.759 (+/-0.022) for {'n_neighbors': 18, 'p': 1, 'weights': 'distance'}
# 0.651 (+/-0.016) for {'n_neighbors': 18, 'p': 2, 'weights': 'uniform'}
# 0.713 (+/-0.018) for {'n_neighbors': 18, 'p': 2, 'weights': 'distance'}
# 0.631 (+/-0.016) for {'n_neighbors': 18, 'p': 3, 'weights': 'uniform'}
# 0.693 (+/-0.015) for {'n_neighbors': 18, 'p': 3, 'weights': 'distance'}
# 0.663 (+/-0.035) for {'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# 0.751 (+/-0.025) for {'n_neighbors': 19, 'p': 1, 'weights': 'distance'}
# 0.646 (+/-0.024) for {'n_neighbors': 19, 'p': 2, 'weights': 'uniform'}
# 0.706 (+/-0.022) for {'n_neighbors': 19, 'p': 2, 'weights': 'distance'}
# 0.626 (+/-0.010) for {'n_neighbors': 19, 'p': 3, 'weights': 'uniform'}
# 0.685 (+/-0.024) for {'n_neighbors': 19, 'p': 3, 'weights': 'distance'}
# 0.662 (+/-0.031) for {'n_neighbors': 20, 'p': 1, 'weights': 'uniform'}
# 0.753 (+/-0.025) for {'n_neighbors': 20, 'p': 1, 'weights': 'distance'}
# 0.653 (+/-0.020) for {'n_neighbors': 20, 'p': 2, 'weights': 'uniform'}
# 0.708 (+/-0.024) for {'n_neighbors': 20, 'p': 2, 'weights': 'distance'}
# 0.633 (+/-0.024) for {'n_neighbors': 20, 'p': 3, 'weights': 'uniform'}
# 0.685 (+/-0.014) for {'n_neighbors': 20, 'p': 3, 'weights': 'distance'}
# 0.667 (+/-0.023) for {'n_neighbors': 21, 'p': 1, 'weights': 'uniform'}
# 0.753 (+/-0.026) for {'n_neighbors': 21, 'p': 1, 'weights': 'distance'}
# 0.658 (+/-0.020) for {'n_neighbors': 21, 'p': 2, 'weights': 'uniform'}
# 0.711 (+/-0.020) for {'n_neighbors': 21, 'p': 2, 'weights': 'distance'}
# 0.621 (+/-0.023) for {'n_neighbors': 21, 'p': 3, 'weights': 'uniform'}
# 0.686 (+/-0.023) for {'n_neighbors': 21, 'p': 3, 'weights': 'distance'}
# 0.668 (+/-0.024) for {'n_neighbors': 22, 'p': 1, 'weights': 'uniform'}
# 0.752 (+/-0.030) for {'n_neighbors': 22, 'p': 1, 'weights': 'distance'}
# 0.656 (+/-0.015) for {'n_neighbors': 22, 'p': 2, 'weights': 'uniform'}
# 0.707 (+/-0.019) for {'n_neighbors': 22, 'p': 2, 'weights': 'distance'}
# 0.624 (+/-0.018) for {'n_neighbors': 22, 'p': 3, 'weights': 'uniform'}
# 0.687 (+/-0.025) for {'n_neighbors': 22, 'p': 3, 'weights': 'distance'}
# 0.673 (+/-0.024) for {'n_neighbors': 23, 'p': 1, 'weights': 'uniform'}
# 0.749 (+/-0.024) for {'n_neighbors': 23, 'p': 1, 'weights': 'distance'}
# 0.644 (+/-0.029) for {'n_neighbors': 23, 'p': 2, 'weights': 'uniform'}
# 0.711 (+/-0.022) for {'n_neighbors': 23, 'p': 2, 'weights': 'distance'}
# 0.609 (+/-0.019) for {'n_neighbors': 23, 'p': 3, 'weights': 'uniform'}
# 0.676 (+/-0.024) for {'n_neighbors': 23, 'p': 3, 'weights': 'distance'}
# 0.668 (+/-0.027) for {'n_neighbors': 24, 'p': 1, 'weights': 'uniform'}
# 0.747 (+/-0.028) for {'n_neighbors': 24, 'p': 1, 'weights': 'distance'}
# 0.648 (+/-0.030) for {'n_neighbors': 24, 'p': 2, 'weights': 'uniform'}
# 0.705 (+/-0.026) for {'n_neighbors': 24, 'p': 2, 'weights': 'distance'}
# 0.610 (+/-0.020) for {'n_neighbors': 24, 'p': 3, 'weights': 'uniform'}
# 0.684 (+/-0.024) for {'n_neighbors': 24, 'p': 3, 'weights': 'distance'}
# 0.666 (+/-0.021) for {'n_neighbors': 25, 'p': 1, 'weights': 'uniform'}
# 0.749 (+/-0.027) for {'n_neighbors': 25, 'p': 1, 'weights': 'distance'}
# 0.636 (+/-0.030) for {'n_neighbors': 25, 'p': 2, 'weights': 'uniform'}
# 0.701 (+/-0.026) for {'n_neighbors': 25, 'p': 2, 'weights': 'distance'}
# 0.615 (+/-0.025) for {'n_neighbors': 25, 'p': 3, 'weights': 'uniform'}
# 0.680 (+/-0.024) for {'n_neighbors': 25, 'p': 3, 'weights': 'distance'}
# 0.661 (+/-0.013) for {'n_neighbors': 26, 'p': 1, 'weights': 'uniform'}
# 0.742 (+/-0.019) for {'n_neighbors': 26, 'p': 1, 'weights': 'distance'}
# 0.644 (+/-0.035) for {'n_neighbors': 26, 'p': 2, 'weights': 'uniform'}
# 0.703 (+/-0.029) for {'n_neighbors': 26, 'p': 2, 'weights': 'distance'}
# 0.621 (+/-0.025) for {'n_neighbors': 26, 'p': 3, 'weights': 'uniform'}
# 0.687 (+/-0.027) for {'n_neighbors': 26, 'p': 3, 'weights': 'distance'}
# 0.659 (+/-0.011) for {'n_neighbors': 27, 'p': 1, 'weights': 'uniform'}
# 0.744 (+/-0.020) for {'n_neighbors': 27, 'p': 1, 'weights': 'distance'}
# 0.637 (+/-0.030) for {'n_neighbors': 27, 'p': 2, 'weights': 'uniform'}
# 0.703 (+/-0.025) for {'n_neighbors': 27, 'p': 2, 'weights': 'distance'}
# 0.620 (+/-0.027) for {'n_neighbors': 27, 'p': 3, 'weights': 'uniform'}
# 0.688 (+/-0.021) for {'n_neighbors': 27, 'p': 3, 'weights': 'distance'}
# 0.659 (+/-0.015) for {'n_neighbors': 28, 'p': 1, 'weights': 'uniform'}
# 0.740 (+/-0.021) for {'n_neighbors': 28, 'p': 1, 'weights': 'distance'}
# 0.648 (+/-0.023) for {'n_neighbors': 28, 'p': 2, 'weights': 'uniform'}
# 0.700 (+/-0.022) for {'n_neighbors': 28, 'p': 2, 'weights': 'distance'}
# 0.620 (+/-0.026) for {'n_neighbors': 28, 'p': 3, 'weights': 'uniform'}
# 0.682 (+/-0.026) for {'n_neighbors': 28, 'p': 3, 'weights': 'distance'}
# 0.653 (+/-0.015) for {'n_neighbors': 29, 'p': 1, 'weights': 'uniform'}
# 0.738 (+/-0.014) for {'n_neighbors': 29, 'p': 1, 'weights': 'distance'}
# 0.643 (+/-0.025) for {'n_neighbors': 29, 'p': 2, 'weights': 'uniform'}
# 0.702 (+/-0.021) for {'n_neighbors': 29, 'p': 2, 'weights': 'distance'}
# 0.619 (+/-0.024) for {'n_neighbors': 29, 'p': 3, 'weights': 'uniform'}
# 0.684 (+/-0.025) for {'n_neighbors': 29, 'p': 3, 'weights': 'distance'}
# 0.647 (+/-0.026) for {'n_neighbors': 30, 'p': 1, 'weights': 'uniform'}
# 0.739 (+/-0.013) for {'n_neighbors': 30, 'p': 1, 'weights': 'distance'}
# 0.641 (+/-0.022) for {'n_neighbors': 30, 'p': 2, 'weights': 'uniform'}
# 0.701 (+/-0.025) for {'n_neighbors': 30, 'p': 2, 'weights': 'distance'}
# 0.621 (+/-0.019) for {'n_neighbors': 30, 'p': 3, 'weights': 'uniform'}
# 0.686 (+/-0.026) for {'n_neighbors': 30, 'p': 3, 'weights': 'distance'}
# Detailed classification report:
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.77      0.75       259
#          1.0       0.46      0.40      0.43       125
#
#     accuracy                           0.65       384
#    macro avg       0.59      0.59      0.59       384
# weighted avg       0.64      0.65      0.64       384
#
#
# Testing score:  0.6443393074362175
#
# Training Score:  1.0
